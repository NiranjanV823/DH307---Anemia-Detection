# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('Tongue_Features.xlsx')

# %%
df.head()
# Out:
#           Image_Name  Hb Value  Gender  Age  Height  Weight    Mean_Red  \
# 0  1709617694248.jpg      11.5       1   63   150.0      42  159.771378
# 1  1709617844626.jpg      11.6       0   63   155.0      55  151.639755
# 2  1709619191362.jpg      11.1       1   50   151.0      45  176.010010
# 3  1709619874657.jpg      12.1       1   42   155.0      45  149.421051
# 4  1709620272757.jpg      12.2       1   76   148.0      60  189.134094
#
#    Mean_Green   Mean_Blue   Mean_R-G  ...  Brightness   Entropy      Mean_L  \
# 0   87.992371   90.381073  72.005806  ...  107.923236  1.248552  115.861465
# 1   84.377701   87.682304  67.432388  ...  103.293337  1.057849  110.123398
# 2  102.283890  106.107758  74.089050  ...  122.548844  1.126287  130.163193
# 3   75.676376   78.948418  73.632431  ...   96.605043  1.567002  104.459190
# 4  132.808350  143.938828  57.631462  ...  148.581877  1.609267  154.929749
#
#        Mean_A      Mean_B    Mean_G1    Mean_G2   Mean_G3    Mean_G4  \
# 0  158.225204  140.570099  25.243435  22.514235  0.785622  10.964525
# 1  156.468307  139.133728  24.914986  25.730181  0.710780  11.430051
# 2  158.666702  139.921814  23.885006  20.850761  1.019817  10.767847
# 3  159.257706  140.929092  20.606983  20.708788  0.620971   9.259699
# 4  151.998764  131.916550  22.450829  19.083355  0.785495  10.425113
#
#       Mean_G5
# 0  112.031242
# 1  106.910942
# 2  127.253647
# 3   99.757233
# 4  153.213547
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416 entries, 0 to 415
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Image_Name       416 non-null    object
#  1   Hb Value         416 non-null    float64
#  2   Gender           416 non-null    int64
#  3   Age              416 non-null    int64
#  4   Height           416 non-null    float64
#  5   Weight           416 non-null    int64
#  6   Mean_Red         416 non-null    float64
#  7   Mean_Green       416 non-null    float64
#  8   Mean_Blue        416 non-null    float64
#  9   Mean_R-G         416 non-null    float64
#  10  Erythema_Index   416 non-null    float64
#  11  Mean_Hue         416 non-null    float64
#  12  Mean_Saturation  416 non-null    float64
#  13  Mean_Value       416 non-null    float64
#  14  High_Hue_Ratio   416 non-null    float64
#  15  Brightness       416 non-null    float64
#  16  Entropy          416 non-null    float64
#  17  Mean_L           416 non-null    float64
#  18  Mean_A           416 non-null    float64
#  19  Mean_B           416 non-null    float64
#  20  Mean_G1          416 non-null    float64
#  21  Mean_G2          416 non-null    float64
#  22  Mean_G3          416 non-null    float64
#  23  Mean_G4          416 non-null    float64
#  24  Mean_G5          416 non-null    float64
# dtypes: float64(21), int64(3), object(1)
# memory usage: 81.4+ KB

# %%
df.isnull().sum()
# Out:
# Image_Name         0
# Hb Value           0
# Gender             0
# Age                0
# Height             0
# Weight             0
# Mean_Red           0
# Mean_Green         0
# Mean_Blue          0
# Mean_R-G           0
# Erythema_Index     0
# Mean_Hue           0
# Mean_Saturation    0
# Mean_Value         0
# High_Hue_Ratio     0
# Brightness         0
# Entropy            0
# Mean_L             0
# Mean_A             0
# Mean_B             0
# Mean_G1            0
# Mean_G2            0
# Mean_G3            0
# Mean_G4            0
# Mean_G5            0
# dtype: int64

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df["Hb Value"], kde=True, bins=20)
plt.title("Distribution of Hb Value")
plt.xlabel("Hb Value")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(13, 8))
sns.heatmap(df.iloc[:, 1:].corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
# Drop non-numeric columns
features = df.drop(columns=["Image_Name", "Hb Value", "Gender"]).columns  # Exclude Gender from feature list

# Generate individual plots
for feature in features:
    plt.figure(figsize=(8, 5))
    sns.scatterplot(x=df[feature], y=df["Hb Value"], hue=df["Gender"], palette="Set2", alpha=0.7)
    plt.xlabel(feature)
    plt.ylabel("Hb Value")
    plt.title(f"Hb Value vs {feature} (Colored by Gender)")
    plt.legend(title="Gender")
    plt.show()  # Show each plot separately
