# %%
import os
import zipfile

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 29.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
dataset_path = '/kaggle/input/left-palm-dataset'

# %%
zip_path = os.path.join(dataset_path, "Images_left_palm/Images_left_palm")

# %%
output_dir = "/kaggle/working/output"

# %%
default_file = os.path.join(dataset_path, "default.txt")

# %%
model_path = os.path.join(dataset_path, "my_model.pt")

# %%
os.listdir('/kaggle/input')
# Out:
# ['left-palm-dataset']

# %%
os.makedirs(output_dir, exist_ok=True)

# %%
model = YOLO(model_path)

# %%
with open(default_file, "r") as f:
    image_names = {line.strip() + ".jpg" for line in f.readlines()}  # Append .jpg

# %%
# Process only images listed in default.txt
for image_name in image_names:
    image_path = os.path.join(zip_path, image_name)  # Use extracted folder
    
    if os.path.exists(image_path):  # Check if image exists
        # Perform inference using YOLO model
        results = model(image_path)

        # Save each processed image in the output folder
        for result in results:
            output_path = os.path.join(output_dir, image_name)
            result.save(filename=output_path)  # Save segmented image with same name
# Out:
# image 1/1 /kaggle/input/left-palm-dataset/Images_left_palm/Images_left_palm/1709643796792.jpg: 640x640 1 color_palette, 41.9ms
# Speed: 13.1ms preprocess, 41.9ms inference, 220.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/input/left-palm-dataset/Images_left_palm/Images_left_palm/1710071277236.jpg: 640x640 1 color_palette, 42.6ms
# Speed: 3.9ms preprocess, 42.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/input/left-palm-dataset/Images_left_palm/Images_left_palm/1709627822607.jpg: 640x640 1 color_palette, 42.0ms
# Speed: 2.5ms preprocess, 42.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/input/left-palm-dataset/Images_left_palm/Images_left_palm/1709810564770.jpg: 640x640 1 color_palette, 40.9ms
# Speed: 2.8ms preprocess, 40.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# ...

# %%
import shutil

# %%
shutil.make_archive("/kaggle/working/output", 'zip', output_dir)
# Out:
# '/kaggle/working/output.zip'
