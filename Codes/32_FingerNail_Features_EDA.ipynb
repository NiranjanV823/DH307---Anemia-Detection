# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('FingerNail_Features.xlsx')

# %%
df.head()
# Out:
#           Image_Name  Hb Value  Gender  Age  Height  Weight    Mean_Red  \
# 0  1709617374918.jpg      11.5       1   63   150.0      42  138.606735
# 1  1709617703730.jpg      11.6       0   63   155.0      55  163.522308
# 2  1709618658975.jpg      11.1       1   50   151.0      45  128.885925
# 3  1709619498294.jpg      12.1       1   42   155.0      45  147.055420
# 4  1709620017738.jpg      12.2       1   76   148.0      60  147.698196
#
#    Mean_Green   Mean_Blue   Mean_R-G  ...  Brightness   Entropy      Mean_L  \
# 0   92.703957   82.860825  48.400242  ...   94.860514  0.161835  106.644852
# 1  133.304199  128.327576  35.787098  ...  133.348545  0.384943  143.963776
# 2   86.655060   83.011177  43.607315  ...   91.597666  0.255604  101.135132
# 3   94.376381   83.437386  54.422375  ...  101.526466  0.363412  112.458321
# 4  108.049637  104.699692  42.440662  ...  112.915589  0.392463  122.273796
#
#        Mean_A      Mean_B    Mean_G1    Mean_G2   Mean_G3    Mean_G4  \
# 0  148.352493  142.836365  41.225063  24.367199  4.813530  19.873451
# 1  141.686874  136.985916  33.229301  20.028419  3.434504  15.541560
# 2  146.415466  139.223053  28.985512  19.525328  2.999077  13.878590
# 3  150.253754  144.512558  25.358034  15.315536  2.720641  11.993537
# 4  145.091568  137.814453  26.433331  17.215773  2.404404  12.501428
#
#       Mean_G5
# 0  118.198151
# 1  150.014755
# 2  106.227722
# 3  117.244637
# 4  126.604927
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 417 entries, 0 to 416
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Image_Name       417 non-null    object
#  1   Hb Value         417 non-null    float64
#  2   Gender           417 non-null    int64
#  3   Age              417 non-null    int64
#  4   Height           417 non-null    float64
#  5   Weight           417 non-null    int64
#  6   Mean_Red         417 non-null    float64
#  7   Mean_Green       417 non-null    float64
#  8   Mean_Blue        417 non-null    float64
#  9   Mean_R-G         417 non-null    float64
#  10  Erythema_Index   417 non-null    float64
#  11  Mean_Hue         417 non-null    float64
#  12  Mean_Saturation  417 non-null    float64
#  13  Mean_Value       417 non-null    float64
#  14  High_Hue_Ratio   417 non-null    float64
#  15  Brightness       417 non-null    float64
#  16  Entropy          417 non-null    float64
#  17  Mean_L           417 non-null    float64
#  18  Mean_A           417 non-null    float64
#  19  Mean_B           417 non-null    float64
#  20  Mean_G1          417 non-null    float64
#  21  Mean_G2          417 non-null    float64
#  22  Mean_G3          417 non-null    float64
#  23  Mean_G4          417 non-null    float64
#  24  Mean_G5          417 non-null    float64
# dtypes: float64(21), int64(3), object(1)
# memory usage: 81.6+ KB

# %%
df.isnull().sum()
# Out:
# Image_Name         0
# Hb Value           0
# Gender             0
# Age                0
# Height             0
# Weight             0
# Mean_Red           0
# Mean_Green         0
# Mean_Blue          0
# Mean_R-G           0
# Erythema_Index     0
# Mean_Hue           0
# Mean_Saturation    0
# Mean_Value         0
# High_Hue_Ratio     0
# Brightness         0
# Entropy            0
# Mean_L             0
# Mean_A             0
# Mean_B             0
# Mean_G1            0
# Mean_G2            0
# Mean_G3            0
# Mean_G4            0
# Mean_G5            0
# dtype: int64

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df["Hb Value"], kde=True, bins=20)
plt.title("Distribution of Hb Value")
plt.xlabel("Hb Value")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(13, 8))
sns.heatmap(df.iloc[:, 1:].corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
# Drop non-numeric columns
features = df.drop(columns=["Image_Name", "Hb Value", "Gender"]).columns  # Exclude Gender from feature list

# Generate individual plots
for feature in features:
    plt.figure(figsize=(8, 5))
    sns.scatterplot(x=df[feature], y=df["Hb Value"], hue=df["Gender"], palette="Set2", alpha=0.7)
    plt.xlabel(feature)
    plt.ylabel("Hb Value")
    plt.title(f"Hb Value vs {feature} (Colored by Gender)")
    plt.legend(title="Gender")
    plt.show()  # Show each plot separately
