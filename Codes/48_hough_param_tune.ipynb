# %%
import cv2
import numpy as np
import os

# Folder containing the cropped palette images
folder_path = "../Produced Images/Eye Palette Yolo Cropped"

# List to store images with incorrect number of circles
invalid_images = []

# Loop through all files in the folder
for filename in os.listdir(folder_path):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
        image_path = os.path.join(folder_path, filename)
        img = cv2.imread(image_path)
        if img is None:
            print(f"Failed to load {filename}")
            continue

        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        gray_blurred = cv2.medianBlur(gray, 5)

        circles = cv2.HoughCircles(
            gray_blurred,
            cv2.HOUGH_GRADIENT,
            dp=1,
            minDist=20,
            param1=50,
            param2=30,
            minRadius=50,
            maxRadius=90
        )

        if circles is not None:
            circles = np.uint16(np.around(circles[0]))
            if len(circles) != 5:
                invalid_images.append((filename, len(circles)))
        else:
            invalid_images.append((filename, 0))

# Output images with incorrect number of circles
if invalid_images:
    print("\nImages with circle count not equal to 5:")
    for fname, count in invalid_images:
        print(f"{fname}: {count} circles detected")
else:
    print("All images have exactly 5 circles.")
# Out:
# Images with circle count not equal to 5:
# 1710062524242.jpg: 7 circles detected
# 1710063043894.jpg: 6 circles detected
# 1710063172053.jpg: 7 circles detected
# 1710067687562.jpg: 2 circles detected
# 1710067886551.jpg: 7 circles detected
# 1710068440387.jpg: 7 circles detected
# 1710068554866.jpg: 11 circles detected
# 1710068975944.jpg: 4 circles detected
# 1710070192681.jpg: 6 circles detected
# 1710070472314.jpg: 4 circles detected
# 1710071755958.jpg: 8 circles detected
# 1709809702881.jpg: 8 circles detected
# 1709809921688.jpg: 3 circles detected
# 1709810155552.jpg: 6 circles detected
# 1709810641319.jpg: 4 circles detected
# 1709873745232.jpg: 7 circles detected
# 1709874072267.jpg: 6 circles detected
# 1709874405956.jpg: 10 circles detected
# 1709874669354.jpg: 8 circles detected
# 1709875256185.jpg: 7 circles detected
# 1709876070273.jpg: 8 circles detected
# 1709876461016.jpg: 12 circles detected
# 1709876699267.jpg: 3 circles detected
# 1709876967453.jpg: 7 circles detected
# 1709714097263.jpg: 4 circles detected
# 1709714149295.jpg: 4 circles detected
# 1709715028843.jpg: 6 circles detected
# 1709715935473.jpg: 9 circles detected
# 1709720371526.jpg: 6 circles detected
# 1709721325478.jpg: 7 circles detected
# 1709721487943.jpg: 4 circles detected
# 1709722173091.jpg: 4 circles detected
# 1709722295062.jpg: 10 circles detected
# 1709723256153.jpg: 6 circles detected
# 1709723311215.jpg: 4 circles detected
# 1709724582307.jpg: 8 circles detected
# 1709724896732.jpg: 3 circles detected
# 1709725187979.jpg: 4 circles detected
# 1709968419454.jpg: 6 circles detected
# 1709968681326.jpg: 6 circles detected
# 1709968993824.jpg: 7 circles detected
# 1709969361635.jpg: 4 circles detected
# 1709969657931.jpg: 7 circles detected
# 1709970267160.jpg: 7 circles detected
# 1709970896072.jpg: 3 circles detected
# 1709971446069.jpg: 7 circles detected
# 1709973325870.jpg: 6 circles detected
# 1709973568143.jpg: 9 circles detected
# 1709973737086.jpg: 7 circles detected
# 1709644066122.jpg: 4 circles detected
# 1709701513633.jpg: 7 circles detected
# 1709703350525.jpg: 7 circles detected
# 1709704104403.jpg: 4 circles detected
# 1709704681372.jpg: 9 circles detected
# 1709625767070.jpg: 6 circles detected
# 1709636657666.jpg: 4 circles detected
# 1709792906801.jpg: 4 circles detected
# 1709877314410.jpg: 7 circles detected
# 1709984416598.jpg: 6 circles detected
# 1709793591996.jpg: 8 circles detected
# 1709793895139.jpg: 7 circles detected
# 1709794234019.jpg: 6 circles detected
# 1709794555949.jpg: 6 circles detected
# 1709794689231.jpg: 9 circles detected
# 1709795232997.jpg: 3 circles detected
# 1709795418986.jpg: 11 circles detected
# 1709795441057.jpg: 6 circles detected
# 1709795753222.jpg: 4 circles detected
# 1709796151230.jpg: 6 circles detected
# 1709796617422.jpg: 6 circles detected
# 1709796724284.jpg: 3 circles detected
# 1709797290722.jpg: 2 circles detected
# 1709797926443.jpg: 8 circles detected
# 1709798819106.jpg: 9 circles detected
# 1709984908128.jpg: 6 circles detected
# 1709985195982.jpg: 8 circles detected
# 1709986283053.jpg: 4 circles detected
# 1710047845630.jpg: 3 circles detected
# 1710048600570.jpg: 3 circles detected
# 1710048884611.jpg: 4 circles detected
# 1710049249967.jpg: 6 circles detected
# 1710049672550.jpg: 9 circles detected
# 1710049803420.jpg: 6 circles detected
# 1710050083980.jpg: 6 circles detected
# 1709883505879.jpg: 10 circles detected
# 1709885384509.jpg: 4 circles detected
# 1709885754910.jpg: 4 circles detected
# 1709885776309.jpg: 6 circles detected
# 1709885965388.jpg: 8 circles detected
# 1709886083067.jpg: 4 circles detected
# 1709887308936.jpg: 3 circles detected
# 1709887581367.jpg: 6 circles detected
# 1709887979543.jpg: 4 circles detected
# 1709892091584.jpg: 7 circles detected
# 1709892770918.jpg: 6 circles detected
# 1709625767525.jpg: 6 circles detected
# 1709626383934.jpg: 4 circles detected
# 1709626920925.jpg: 4 circles detected
# 1709628184089.jpg: 4 circles detected
# 1709628406462.jpg: 4 circles detected
# 1709630906630.jpg: 7 circles detected
# 1709634401216.jpg: 3 circles detected
# 1709634858094.jpg: 4 circles detected
# 1709635096689.jpg: 4 circles detected
# 1709636451463.jpg: 8 circles detected
# 1710051244745.jpg: 10 circles detected
# 1710051565002.jpg: 6 circles detected
# 1710052344015.jpg: 3 circles detected
# 1710052769756.jpg: 6 circles detected
# 1710054141484.jpg: 8 circles detected
# 1710054571640.jpg: 6 circles detected
# 1710054990617.jpg: 6 circles detected
# 1710055434537.jpg: 6 circles detected
# 1710057668770.jpg: 9 circles detected
# 1710058875574.jpg: 3 circles detected
# 1710059893236.jpg: 6 circles detected
# 1710060134155.jpg: 3 circles detected
# 1710060443557.jpg: 3 circles detected
# 1710060707595.jpg: 8 circles detected
# 1710061256381.jpg: 4 circles detected
# 1709705027210.jpg: 6 circles detected
# 1709707373672.jpg: 4 circles detected
# 1709707651859.jpg: 6 circles detected
# 1709707900867.jpg: 7 circles detected
# 1709708285953.jpg: 9 circles detected
# 1709708693765.jpg: 4 circles detected
# 1709709085751.jpg: 4 circles detected
# 1709709259763.jpg: 4 circles detected
# 1709709442590.jpg: 3 circles detected
# 1709709970921.jpg: 3 circles detected
# 1709710126239.jpg: 4 circles detected
# 1709710614773.jpg: 4 circles detected
# 1709711165890.jpg: 6 circles detected
# 1709712138693.jpg: 8 circles detected
# 1709712231613.jpg: 3 circles detected
# 1709712668361.jpg: 6 circles detected
# 1709713709275.jpg: 10 circles detected
# 1709726773680.jpg: 10 circles detected
# 1709788857606.jpg: 4 circles detected
# 1709789179906.jpg: 4 circles detected
# 1709789649074.jpg: 6 circles detected
# 1709789672580.jpg: 4 circles detected
# 1709790442782.jpg: 6 circles detected
# 1709790989339.jpg: 7 circles detected
# 1709791740029.jpg: 9 circles detected
# 1709792279265.jpg: 4 circles detected
# 1709792869244.jpg: 9 circles detected
# 1709877626672.jpg: 6 circles detected
# 1709877779920.jpg: 4 circles detected
# 1709878237242.jpg: 6 circles detected
# 1709878709386.jpg: 2 circles detected
# 1709879494259.jpg: 6 circles detected
# 1709880263138.jpg: 6 circles detected
# 1709880362990.jpg: 7 circles detected
# 1709880494391.jpg: 11 circles detected
# 1709880958803.jpg: 4 circles detected
# 1709974131918.jpg: 6 circles detected
# 1709974424897.jpg: 4 circles detected
# 1709974483896.jpg: 6 circles detected
# 1709974996470.jpg: 6 circles detected
# 1709975292366.jpg: 3 circles detected
# 1709975472792.jpg: 1 circles detected
# 1709976267193.jpg: 7 circles detected
# 1709976624062.jpg: 6 circles detected
# 1709977206296.jpg: 10 circles detected
# 1709981218177.jpg: 6 circles detected
# 1709981686755.jpg: 4 circles detected
# 1709982473883.jpg: 8 circles detected
# 1709982560073.jpg: 7 circles detected
# 1709983832661.jpg: 7 circles detected
# 1709983961613.jpg: 3 circles detected
# 1709984108041.jpg: 8 circles detected
# 1709799789148.jpg: 4 circles detected
# 1709799981476.jpg: 6 circles detected
# 1709800069998.jpg: 2 circles detected
# 1709800733671.jpg: 8 circles detected
# 1709801070971.jpg: 6 circles detected
# 1709801109386.jpg: 6 circles detected
# 1709801588302.jpg: 11 circles detected
# 1709801715764.jpg: 4 circles detected
# 1709806223164.jpg: 6 circles detected
# 1709806681433.jpg: 8 circles detected
# 1709806918462.jpg: 7 circles detected
# 1709808245991.jpg: 6 circles detected
# 1709808448604.jpg: 4 circles detected
# 1709808682571.jpg: 6 circles detected
# 1709894149617.jpg: 8 circles detected
# 1709894410795.jpg: 4 circles detected
# 1709895095707.jpg: 6 circles detected
# 1709895764472.jpg: 1 circles detected
# 1709895828777.jpg: 6 circles detected
# 1709964724278.jpg: 9 circles detected
# 1709964941995.jpg: 4 circles detected
# 1709965309113.jpg: 6 circles detected
# 1709965728812.jpg: 8 circles detected
# 1709965939123.jpg: 7 circles detected
# 1709967291627.jpg: 6 circles detected
# 1709637079415.jpg: 4 circles detected
# 1709637853296.jpg: 4 circles detected
# 1709638681606.jpg: 4 circles detected
# 1709638762739.jpg: 6 circles detected
# 1709639773324.jpg: 4 circles detected
# 1709640071223.jpg: 4 circles detected
# 1709640822554.jpg: 4 circles detected
# 1709641063307.jpg: 7 circles detected
# 1709642420649.jpg: 8 circles detected
# 1709642701745.jpg: 4 circles detected
# 1709642929674.jpg: 7 circles detected
# 1709643716953.jpg: 7 circles detected
# 1709618916134.jpg: 6 circles detected
# 1709619661748.jpg: 6 circles detected
# 1709620146694.jpg: 2 circles detected
# 1709620595216.jpg: 6 circles detected
# 1709621062603.jpg: 3 circles detected
# 1709621597176.jpg: 6 circles detected
# 1709624290874.jpg: 6 circles detected
# 1709625264664.jpg: 0 circles detected

# %%
import cv2
import numpy as np
import os
from itertools import product

# Folder containing the cropped palette images
folder_path = "../Produced Images/Eye Palette Yolo Cropped"
image_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

# Parameter grids
dp_vals = [1, 1.2, 1.5]
minDist_vals = [10, 20, 30]
param1_vals = [30, 50, 100]
param2_vals = [20, 30, 40]
minRadius_vals = [40, 50, 60]
maxRadius_vals = [80, 90, 100]

# Store best results
best_params = None
max_valid_count = -1

# Try every combination of parameters
for dp, minDist, param1, param2, minRadius, maxRadius in product(
    dp_vals, minDist_vals, param1_vals, param2_vals, minRadius_vals, maxRadius_vals):

    valid_count = 0

    for filename in image_files:
        image_path = os.path.join(folder_path, filename)
        img = cv2.imread(image_path)
        if img is None:
            continue

        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        gray_blurred = cv2.medianBlur(gray, 5)

        circles = cv2.HoughCircles(
            gray_blurred,
            cv2.HOUGH_GRADIENT,
            dp=dp,
            minDist=minDist,
            param1=param1,
            param2=param2,
            minRadius=minRadius,
            maxRadius=maxRadius
        )

        if circles is not None and len(np.uint16(np.around(circles[0]))) == 5:
            valid_count += 1

    if valid_count > max_valid_count:
        max_valid_count = valid_count
        best_params = {
            "dp": dp,
            "minDist": minDist,
            "param1": param1,
            "param2": param2,
            "minRadius": minRadius,
            "maxRadius": maxRadius
        }

# Show best result
print("\nBest Parameters:")
print(best_params)
print(f"Number of images with exactly 5 circles: {max_valid_count} / {len(image_files)}")
# Out:
# Best Parameters:
# {'dp': 1.2, 'minDist': 30, 'param1': 50, 'param2': 30, 'minRadius': 60, 'maxRadius': 90}
# Number of images with exactly 5 circles: 285 / 412

# %%
import cv2
import numpy as np
import os
from itertools import product

# Folder containing the cropped palette images
folder_path = "../Produced Images/Fingernail Palette Yolo Cropped"
image_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

# Parameter grids
dp_vals = [1, 1.2, 1.5]
minDist_vals = [10, 20, 30]
param1_vals = [30, 50, 100]
param2_vals = [20, 30, 40]
minRadius_vals = [40, 50, 60]
maxRadius_vals = [80, 90, 100]

# Store best results
best_params = None
max_valid_count = -1

# Try every combination of parameters
for dp, minDist, param1, param2, minRadius, maxRadius in product(
    dp_vals, minDist_vals, param1_vals, param2_vals, minRadius_vals, maxRadius_vals):

    valid_count = 0

    for filename in image_files:
        image_path = os.path.join(folder_path, filename)
        img = cv2.imread(image_path)
        if img is None:
            continue

        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        gray_blurred = cv2.medianBlur(gray, 5)

        circles = cv2.HoughCircles(
            gray_blurred,
            cv2.HOUGH_GRADIENT,
            dp=dp,
            minDist=minDist,
            param1=param1,
            param2=param2,
            minRadius=minRadius,
            maxRadius=maxRadius
        )

        if circles is not None and len(np.uint16(np.around(circles[0]))) == 5:
            valid_count += 1

    if valid_count > max_valid_count:
        max_valid_count = valid_count
        best_params = {
            "dp": dp,
            "minDist": minDist,
            "param1": param1,
            "param2": param2,
            "minRadius": minRadius,
            "maxRadius": maxRadius
        }

# Show best result
print("\nBest Parameters:")
print(best_params)
print(f"Number of images with exactly 5 circles: {max_valid_count} / {len(image_files)}")
# Out:
# Best Parameters:
# {'dp': 1, 'minDist': 30, 'param1': 50, 'param2': 30, 'minRadius': 40, 'maxRadius': 100}
# Number of images with exactly 5 circles: 416 / 425

# %%
import cv2
import numpy as np
import os
from itertools import product

# Folder containing the cropped palette images
folder_path = "../Produced Images/Palm Palette Yolo Cropped"
image_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

# Parameter grids
dp_vals = [1, 1.2, 1.5]
minDist_vals = [10, 20, 30]
param1_vals = [30, 50, 100]
param2_vals = [20, 30, 40]
minRadius_vals = [40, 50, 60]
maxRadius_vals = [80, 90, 100]

# Store best results
best_params = None
max_valid_count = -1

# Try every combination of parameters
for dp, minDist, param1, param2, minRadius, maxRadius in product(
    dp_vals, minDist_vals, param1_vals, param2_vals, minRadius_vals, maxRadius_vals):

    valid_count = 0

    for filename in image_files:
        image_path = os.path.join(folder_path, filename)
        img = cv2.imread(image_path)
        if img is None:
            continue

        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        gray_blurred = cv2.medianBlur(gray, 5)

        circles = cv2.HoughCircles(
            gray_blurred,
            cv2.HOUGH_GRADIENT,
            dp=dp,
            minDist=minDist,
            param1=param1,
            param2=param2,
            minRadius=minRadius,
            maxRadius=maxRadius
        )

        if circles is not None and len(np.uint16(np.around(circles[0]))) == 5:
            valid_count += 1

    if valid_count > max_valid_count:
        max_valid_count = valid_count
        best_params = {
            "dp": dp,
            "minDist": minDist,
            "param1": param1,
            "param2": param2,
            "minRadius": minRadius,
            "maxRadius": maxRadius
        }

# Show best result
print("\nBest Parameters:")
print(best_params)
print(f"Number of images with exactly 5 circles: {max_valid_count} / {len(image_files)}")
# Out:
# Best Parameters:
# {'dp': 1, 'minDist': 30, 'param1': 30, 'param2': 20, 'minRadius': 40, 'maxRadius': 80}
# Number of images with exactly 5 circles: 389 / 426

# %%
import cv2
import numpy as np
import os
from itertools import product

# Folder containing the cropped palette images
folder_path = "../Produced Images/Tongue Palette Yolo Cropped"
image_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

# Parameter grids
dp_vals = [1, 1.2, 1.5]
minDist_vals = [10, 20, 30]
param1_vals = [30, 50, 100]
param2_vals = [20, 30, 40]
minRadius_vals = [40, 50, 60]
maxRadius_vals = [80, 90, 100]

# Store best results
best_params = None
max_valid_count = -1

# Try every combination of parameters
for dp, minDist, param1, param2, minRadius, maxRadius in product(
    dp_vals, minDist_vals, param1_vals, param2_vals, minRadius_vals, maxRadius_vals):

    valid_count = 0

    for filename in image_files:
        image_path = os.path.join(folder_path, filename)
        img = cv2.imread(image_path)
        if img is None:
            continue

        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        gray_blurred = cv2.medianBlur(gray, 5)

        circles = cv2.HoughCircles(
            gray_blurred,
            cv2.HOUGH_GRADIENT,
            dp=dp,
            minDist=minDist,
            param1=param1,
            param2=param2,
            minRadius=minRadius,
            maxRadius=maxRadius
        )

        if circles is not None and len(np.uint16(np.around(circles[0]))) == 5:
            valid_count += 1

    if valid_count > max_valid_count:
        max_valid_count = valid_count
        best_params = {
            "dp": dp,
            "minDist": minDist,
            "param1": param1,
            "param2": param2,
            "minRadius": minRadius,
            "maxRadius": maxRadius
        }

# Show best result
print("\nBest Parameters:")
print(best_params)
print(f"Number of images with exactly 5 circles: {max_valid_count} / {len(image_files)}")
# Out:
# Best Parameters:
# {'dp': 1.2, 'minDist': 30, 'param1': 30, 'param2': 30, 'minRadius': 50, 'maxRadius': 80}
# Number of images with exactly 5 circles: 300 / 425
