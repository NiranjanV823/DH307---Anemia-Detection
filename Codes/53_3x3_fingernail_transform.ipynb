# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt

# Define your folders
palette_folder = "../Produced Images/Fingernail Palette Yolo Cropped"
original_folder = "../Dataset Used/Right Fingernail_files/Images_right_fingernail"
output_folder = "../Produced Images/Fingernail Transformed by 3x3 1"

# Create output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Define reference colors (B, G, R)
# reference_colors = {
#     "black": (0,   0,   0),
#     "white": (255, 255, 255),
#     "red":   (0,   0,   255),
#     "green": (0,   255, 0),
#     "blue":  (255, 0,   0)
# }

reference_colors = {
    "black": (0,   0,   0),
    "white": (255, 255, 255),
    "red":   (41,   34,   159),
    "green": (29,   77, 53),
    "blue":  (67 , 30,  28)
}


# Loop through each file in the palette folder
for filename in os.listdir(palette_folder):
    # Process only image files (adjust extensions as needed)
    if not filename.lower().endswith(('.jpg', '.jpeg', '.png')):
        continue

    palette_path = os.path.join(palette_folder, filename)
    original_path = os.path.join(original_folder, filename)
    
    # Check if the corresponding original image exists
    if not os.path.exists(original_path):
        print(f"Original image not found for {filename}. Skipping...")
        continue

    # Load the palette image
    palette_img = cv2.imread(palette_path)
    if palette_img is None:
        print(f"Error loading palette image: {filename}. Skipping...")
        continue

    # Convert palette image to grayscale and apply median blur
    gray = cv2.cvtColor(palette_img, cv2.COLOR_BGR2GRAY)
    gray_blurred = cv2.medianBlur(gray, 5)

    # Use HoughCircles to detect circles
    circles = cv2.HoughCircles(
        gray_blurred,
        cv2.HOUGH_GRADIENT,
        dp=1,
        minDist=30,
        param1=50,
        param2=30,
        minRadius=40,
        maxRadius=100
    )

    # Proceed only if exactly 5 circles are detected
    if circles is not None:
        circles = np.uint16(np.around(circles[0]))
        if len(circles) != 5:
            print(f"{filename}: Detected {len(circles)} circles (expected 5). Skipping...")
            continue
    else:
        print(f"{filename}: No circles detected. Skipping...")
        continue

    print(f"{filename}: Detected circles (x, y, radius):")
    print(circles)

    measured_colors = []  # To store the average color (B, G, R) for each circle

    # Loop through each detected circle and compute the average color
    for (x, y, r) in circles:
        mask = np.zeros_like(gray, dtype=np.uint8)
        cv2.circle(mask, (x, y), r, 255, -1)
        mean_color = cv2.mean(palette_img, mask=mask)  # (B, G, R, alpha)
        measured_colors.append((mean_color[0], mean_color[1], mean_color[2]))

    print(f"{filename}: Measured colors (B, G, R):")
    for color in measured_colors:
        print(color)

    # Match each measured color to the closest reference color.
    matched_pairs = []  # Each pair is (measured_color, reference_color)
    used_refs = set()

    for mc in measured_colors:
        mc_arr = np.array(mc, dtype=np.float32)
        best_label = None
        best_dist = float("inf")
        
        for label, ref_color in reference_colors.items():
            if label in used_refs:
                continue  # Each reference color is used only once
            ref_arr = np.array(ref_color, dtype=np.float32)
            dist = np.linalg.norm(mc_arr - ref_arr)
            if dist < best_dist:
                best_dist = dist
                best_label = label
                best_ref = ref_color
                
        used_refs.add(best_label)
        matched_pairs.append((mc, best_ref))

    print(f"{filename}: Matched Measured Colors to Reference Colors:")
    for meas, ref in matched_pairs:
        print("Measured:", meas, "-> Reference:", ref)

    # Create arrays from the matched pairs
    meas_arr = np.array([pair[0] for pair in matched_pairs], dtype=np.float32)  # (5, 3)
    ref_arr  = np.array([pair[1] for pair in matched_pairs], dtype=np.float32)  # (5, 3)

    # Compute the color correction matrix M using least squares
    M, residuals, rank, s = np.linalg.lstsq(meas_arr, ref_arr, rcond=None)
    print(f"{filename}: Computed Color Correction Matrix (M):")
    print(M)

    # Load the corresponding original image
    original_img = cv2.imread(original_path)
    if original_img is None:
        print(f"Error loading original image: {filename}. Skipping...")
        continue

    # Reshape the original image to a 2D array of pixels (each pixel is a 3-element vector)
    h, w, c = original_img.shape
    pixels = original_img.reshape((-1, 3)).astype(np.float32)

    # Apply the color correction matrix to each pixel
    corrected_pixels = np.dot(pixels, M)

    # Clamp the pixel values to the valid range [0, 255]
    corrected_pixels = np.clip(corrected_pixels, 0, 255)

    # Reshape back to the original image dimensions and convert to uint8
    corrected_img = corrected_pixels.reshape((h, w, 3)).astype(np.uint8)

    # Save the corrected image in the output folder
    output_path = os.path.join(output_folder, filename)
    cv2.imwrite(output_path, corrected_img)
    print(f"{filename}: Transformed image saved to {output_path}")

# Optionally, display a message when finished processing
print("Processing completed for all images.")
# Out:
# 1710068253661.jpg: Detected circles (x, y, radius):
# [[ 68  64  61]
#  [174 122  62]
#  [ 70 306  62]
#  [ 68 184  60]
#  [176 248  60]]
# 1710068253661.jpg: Measured colors (B, G, R):
# (122.24193134149473, 18.387552435579146, 26.1716462631624)
# (251.24774065168725, 202.69347483624907, 205.94967249813448)
# (64.50766934748363, 46.035154630627645, 188.94859464389353)
# (79.03374966781823, 131.24067676499246, 72.53778013995925)
# (33.546195411462485, 18.994862255292762, 21.636726016476214)
# 1710068253661.jpg: Matched Measured Colors to Reference Colors:
# Measured: (122.24193134149473, 18.387552435579146, 26.1716462631624) -> Reference: (67, 30, 28)
# Measured: (251.24774065168725, 202.69347483624907, 205.94967249813448) -> Reference: (255, 255, 255)
# Measured: (64.50766934748363, 46.035154630627645, 188.94859464389353) -> Reference: (41, 34, 159)
# Measured: (79.03374966781823, 131.24067676499246, 72.53778013995925) -> Reference: (29, 77, 53)
# Measured: (33.546195411462485, 18.994862255292762, 21.636726016476214) -> Reference: (0, 0, 0)
# 1710068253661.jpg: Computed Color Correction Matrix (M):
# [[ 0.802537    0.38254428  0.21608452]
#  [ 0.06209798  0.66225684  0.03945746]
#  [ 0.01517339 -0.03716408  0.814301  ]]
# 1710068253661.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1710068253661.jpg
# 1710068488123.jpg: Detected circles (x, y, radius):
# [[200  82  75]
#  [124 210  70]
#  [282 208  74]
#  [348  78  74]
#  [ 48  86  75]]
# 1710068488123.jpg: Measured colors (B, G, R):
# (80.45808095103312, 130.492442683272, 68.95448627228984)
# (32.097313471671114, 16.1749170623821, 14.39042477070188)
# (253.01494794393068, 198.28581399406735, 195.6350840458326)
# (120.4619903449078, 15.457977083696854, 18.48862909323562)
# (64.69971725999228, 44.22747718802211, 195.33556098187893)
# 1710068488123.jpg: Matched Measured Colors to Reference Colors:
# Measured: (80.45808095103312, 130.492442683272, 68.95448627228984) -> Reference: (29, 77, 53)
# Measured: (32.097313471671114, 16.1749170623821, 14.39042477070188) -> Reference: (0, 0, 0)
# Measured: (253.01494794393068, 198.28581399406735, 195.6350840458326) -> Reference: (255, 255, 255)
# Measured: (120.4619903449078, 15.457977083696854, 18.48862909323562) -> Reference: (67, 30, 28)
# Measured: (64.69971725999228, 44.22747718802211, 195.33556098187893) -> Reference: (41, 34, 159)
# 1710068488123.jpg: Computed Color Correction Matrix (M):
# [[ 0.81828463  0.40357912  0.283751  ]
#  [ 0.04129462  0.6428855   0.04439017]
#  [ 0.01464188 -0.03205047  0.76616865]]
# 1710068488123.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1710068488123.jpg
# 1710068973167.jpg: Detected circles (x, y, radius):
# [[ 60 170  56]
#  [160 232  57]
#  [162 116  59]
#  [ 62  60  56]
#  [ 56 282  57]]
# 1710068973167.jpg: Measured colors (B, G, R):
# (59.97755205688167, 93.33600812595226, 57.03727780599289)
# (20.566198841888312, 10.746883894395918, 13.861909902836393)
# (145.03207184092366, 118.3784477228993, 133.8740951159168)
# (88.46998476383952, 13.800507872016253, 22.02712036566785)
# (47.58990969768355, 26.729191205339617, 145.34982332155477)
# 1710068973167.jpg: Matched Measured Colors to Reference Colors:
# Measured: (59.97755205688167, 93.33600812595226, 57.03727780599289) -> Reference: (29, 77, 53)
# Measured: (20.566198841888312, 10.746883894395918, 13.861909902836393) -> Reference: (0, 0, 0)
# Measured: (145.03207184092366, 118.3784477228993, 133.8740951159168) -> Reference: (41, 34, 159)
# Measured: (88.46998476383952, 13.800507872016253, 22.02712036566785) -> Reference: (67, 30, 28)
# Measured: (47.58990969768355, 26.729191205339617, 145.34982332155477) -> Reference: (255, 255, 255)
# 1710068973167.jpg: Computed Color Correction Matrix (M):
# [[ 0.10333329 -0.5293835  -0.13848105]
#  [-1.4508486  -0.67625207 -0.57199496]
#  [ 1.8471135   1.8812102   1.8848766 ]]
# 1710068973167.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1710068973167.jpg
# 1710069174769.jpg: Detected circles (x, y, radius):
# [[118  64  62]
#  [172 176  60]
#  [244  74  61]
#  [292 186  60]
#  [ 52 168  62]]
# 1710069174769.jpg: Measured colors (B, G, R):
# (222.59671669015836, 182.2405273194594, 192.78376585689412)
# (69.73655771104615, 111.35025245814509, 72.80503144654088)
# (32.85951545244414, 20.905744371201095, 24.389179008646522)
# (54.64584080315526, 35.989333094299035, 179.9378809609179)
# (102.49540338517055, 18.943809605636222, 25.646705043388607)
# 1710069174769.jpg: Matched Measured Colors to Reference Colors:
# Measured: (222.59671669015836, 182.2405273194594, 192.78376585689412) -> Reference: (255, 255, 255)
# Measured: (69.73655771104615, 111.35025245814509, 72.80503144654088) -> Reference: (29, 77, 53)
# Measured: (32.85951545244414, 20.905744371201095, 24.389179008646522) -> Reference: (67, 30, 28)
# Measured: (54.64584080315526, 35.989333094299035, 179.9378809609179) -> Reference: (41, 34, 159)
# Measured: (102.49540338517055, 18.943809605636222, 25.646705043388607) -> Reference: (0, 0, 0)
# 1710069174769.jpg: Computed Color Correction Matrix (M):
# [[0.42723164 0.174374   0.05242468]
#  [0.51997244 0.98682904 0.22956595]
#  [0.10177755 0.01170796 0.88649094]]
# 1710069174769.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1710069174769.jpg
# 1710069438045.jpg: Detected circles (x, y, radius):
# [[130 210  73]
#  [284 216  76]
#  [212  84  74]
#  [360  92  77]
#  [ 62  82  73]]
# 1710069438045.jpg: Measured colors (B, G, R):
# (40.50385558013031, 20.328710622272702, 16.8940163787435)
# (252.7370572959832, 203.99795568815955, 194.48930880159125)
# (65.81376141452917, 106.73692781946141, 56.8278369103705)
# (117.86025262026338, 21.734264982531577, 19.44251545283526)
# (58.52203975799482, 40.88930732189159, 182.99357945425362)
# 1710069438045.jpg: Matched Measured Colors to Reference Colors:
# Measured: (40.50385558013031, 20.328710622272702, 16.8940163787435) -> Reference: (67, 30, 28)
# Measured: (252.7370572959832, 203.99795568815955, 194.48930880159125) -> Reference: (255, 255, 255)
# Measured: (65.81376141452917, 106.73692781946141, 56.8278369103705) -> Reference: (29, 77, 53)
# Measured: (117.86025262026338, 21.734264982531577, 19.44251545283526) -> Reference: (0, 0, 0)
# Measured: (58.52203975799482, 40.88930732189159, 182.99357945425362) -> Reference: (41, 34, 159)
# 1710069438045.jpg: Computed Color Correction Matrix (M):
# [[ 0.2951923   0.04965594 -0.00383359]
#  [ 0.611559    1.0614973   0.34612882]
#  [ 0.09581519  0.00110766  0.8475911 ]]
# 1710069438045.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1710069438045.jpg
# 1710069947356.jpg: Detected circles (x, y, radius):
# [[204 148  72]
#  [ 78  80  70]
#  [ 76 220  70]
#  [202 296  71]
#  [ 78 354  72]]
# 1710069947356.jpg: Measured colors (B, G, R):
# (253.2836032264023, 246.23021981405083, 227.74576688627545)
# (145.40915891498082, 14.277629610355818, 10.141872113445652)
# (89.38756260977038, 142.29759968776426, 68.5959149157614)
# (50.0810725352558, 26.67469803326377, 23.719534560172008)
# (79.63616772366233, 64.81435872175358, 205.52410565851855)
# 1710069947356.jpg: Matched Measured Colors to Reference Colors:
# Measured: (253.2836032264023, 246.23021981405083, 227.74576688627545) -> Reference: (255, 255, 255)
# Measured: (145.40915891498082, 14.277629610355818, 10.141872113445652) -> Reference: (67, 30, 28)
# Measured: (89.38756260977038, 142.29759968776426, 68.5959149157614) -> Reference: (29, 77, 53)
# Measured: (50.0810725352558, 26.67469803326377, 23.719534560172008) -> Reference: (0, 0, 0)
# Measured: (79.63616772366233, 64.81435872175358, 205.52410565851855) -> Reference: (41, 34, 159)
# 1710069947356.jpg: Computed Color Correction Matrix (M):
# [[ 0.5498164   0.21834503  0.1683188 ]
#  [ 0.25512993  0.7295933   0.09577981]
#  [ 0.03243019 -0.05791727  0.7345477 ]]
# 1710069947356.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1710069947356.jpg
# 1710070186245.jpg: Detected circles (x, y, radius):
# [[150  60  50]
#  [250  64  50]
#  [198 152  51]
#  [ 52  58  52]
#  [ 96 150  51]]
# 1710070186245.jpg: Measured colors (B, G, R):
# (66.88336520076481, 111.5631612492033, 75.29866156787762)
# (101.35818992989164, 15.17348629700446, 25.445251752708728)
# (215.13874954117216, 173.55230637464823, 184.50116236388106)
# (61.045780863834295, 33.01706484641638, 176.78145227727433)
# (25.848647987275175, 15.227700966597332, 18.65398262571883)
# 1710070186245.jpg: Matched Measured Colors to Reference Colors:
# Measured: (66.88336520076481, 111.5631612492033, 75.29866156787762) -> Reference: (29, 77, 53)
# Measured: (101.35818992989164, 15.17348629700446, 25.445251752708728) -> Reference: (67, 30, 28)
# Measured: (215.13874954117216, 173.55230637464823, 184.50116236388106) -> Reference: (255, 255, 255)
# Measured: (61.045780863834295, 33.01706484641638, 176.78145227727433) -> Reference: (41, 34, 159)
# Measured: (25.848647987275175, 15.227700966597332, 18.65398262571883) -> Reference: (0, 0, 0)
# 1710070186245.jpg: Computed Color Correction Matrix (M):
# [[ 0.99155164  0.46955174  0.3154007 ]
#  [ 0.10830209  0.78380775  0.03235446]
#  [-0.06928742 -0.0649057   0.8319337 ]]
# 1710070186245.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1710070186245.jpg
# 1710070329704.jpg: Detected circles (x, y, radius):
# [[186 280  67]
#  [186 136  69]
#  [ 76 214  68]
#  [ 76  80  68]
#  [ 70 342  64]]
# 1710070329704.jpg: Measured colors (B, G, R):
# (21.558871598095642, 9.469409507567683, 9.844738151069423)
# (207.55368252056994, 150.16777041942603, 148.91584721386045)
# (64.61185798000689, 94.61206480523957, 49.60944501895897)
# (95.45956566701136, 12.320165460186141, 14.97931747673216)
# (38.97805959698125, 18.00606862211157, 151.7346922897378)
# 1710070329704.jpg: Matched Measured Colors to Reference Colors:
# Measured: (21.558871598095642, 9.469409507567683, 9.844738151069423) -> Reference: (0, 0, 0)
# Measured: (207.55368252056994, 150.16777041942603, 148.91584721386045) -> Reference: (255, 255, 255)
# Measured: (64.61185798000689, 94.61206480523957, 49.60944501895897) -> Reference: (29, 77, 53)
# Measured: (95.45956566701136, 12.320165460186141, 14.97931747673216) -> Reference: (67, 30, 28)
# Measured: (38.97805959698125, 18.00606862211157, 151.7346922897378) -> Reference: (41, 34, 159)
# 1710070329704.jpg: Computed Color Correction Matrix (M):
# [[1.0005964  0.45423856 0.33088538]
#  [0.00883698 0.8192989  0.09885562]
#  [0.09746479 0.08004668 1.0084656 ]]
# 1710070329704.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1710070329704.jpg
# 1710070631584.jpg: Detected circles (x, y, radius):
# [[232  58  56]
#  [122  70  56]
#  [ 78 172  54]
#  [184 162  55]
#  [296 150  56]]
# 1710070631584.jpg: Measured colors (B, G, R):
# (40.465109192483496, 22.805891315388525, 22.55205688166582)
# (252.6233621127476, 211.43108176739463, 202.66998476383952)
# (141.5790049207217, 18.105850191361398, 12.23335155822854)
# (83.2655903767015, 130.99535718054236, 71.99293025218951)
# (64.5630703166935, 46.37208803005904, 188.09125067096082)
# 1710070631584.jpg: Matched Measured Colors to Reference Colors:
# Measured: (40.465109192483496, 22.805891315388525, 22.55205688166582) -> Reference: (67, 30, 28)
# Measured: (252.6233621127476, 211.43108176739463, 202.66998476383952) -> Reference: (255, 255, 255)
# Measured: (141.5790049207217, 18.105850191361398, 12.23335155822854) -> Reference: (29, 77, 53)
# Measured: (83.2655903767015, 130.99535718054236, 71.99293025218951) -> Reference: (41, 34, 159)
# Measured: (64.5630703166935, 46.37208803005904, 188.09125067096082) -> Reference: (0, 0, 0)
# 1710070631584.jpg: Computed Color Correction Matrix (M):
# [[ 0.4376337   0.7453825   0.24830489]
#  [ 0.6256524   0.32917395  1.2862393 ]
#  [-0.16563514 -0.22152132 -0.39951158]]
# 1710070631584.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1710070631584.jpg
# 1710071177238.jpg: Detected circles (x, y, radius):
# [[142 186  59]
#  [124 304  59]
#  [ 50 110  59]
#  [160  70  58]
#  [ 32 232  60]]
# 1710071177238.jpg: Measured colors (B, G, R):
# (79.37185008705214, 123.15366993493998, 59.914597269311834)
# (116.81526619627967, 12.111884907908, 9.971226976999908)
# (39.95562074186223, 18.458175624526874, 16.119133232399697)
# (60.328881310978495, 43.14559060339111, 187.42218433267027)
# (252.00064246707356, 195.86004925580897, 186.24959845807902)
# 1710071177238.jpg: Matched Measured Colors to Reference Colors:
# Measured: (79.37185008705214, 123.15366993493998, 59.914597269311834) -> Reference: (29, 77, 53)
# Measured: (116.81526619627967, 12.111884907908, 9.971226976999908) -> Reference: (67, 30, 28)
# Measured: (39.95562074186223, 18.458175624526874, 16.119133232399697) -> Reference: (0, 0, 0)
# Measured: (60.328881310978495, 43.14559060339111, 187.42218433267027) -> Reference: (41, 34, 159)
# Measured: (252.00064246707356, 195.86004925580897, 186.24959845807902) -> Reference: (255, 255, 255)
# 1710071177238.jpg: Computed Color Correction Matrix (M):
# [[ 0.7999154   0.38310638  0.29458272]
#  [ 0.04889084  0.6779033   0.05788491]
#  [ 0.04316289 -0.02095497  0.7947756 ]]
# 1710071177238.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1710071177238.jpg
# 1710071297670.jpg: Detected circles (x, y, radius):
# [[ 88 206  68]
#  [146  82  70]
#  [224 200  68]
#  [290  74  69]
#  [360 192  68]]
# 1710071297670.jpg: Measured colors (B, G, R):
# (111.30230954843157, 14.368011030679074, 26.441571871768353)
# (236.58134391465558, 185.1244389514083, 195.20275808235218)
# (73.97773181661495, 122.55822130299896, 81.72637021716649)
# (32.60351863000869, 17.58465449193926, 21.716636564318684)
# (62.615035282610215, 27.326346677845315, 187.61440648361628)
# 1710071297670.jpg: Matched Measured Colors to Reference Colors:
# Measured: (111.30230954843157, 14.368011030679074, 26.441571871768353) -> Reference: (67, 30, 28)
# Measured: (236.58134391465558, 185.1244389514083, 195.20275808235218) -> Reference: (255, 255, 255)
# Measured: (73.97773181661495, 122.55822130299896, 81.72637021716649) -> Reference: (29, 77, 53)
# Measured: (32.60351863000869, 17.58465449193926, 21.716636564318684) -> Reference: (0, 0, 0)
# Measured: (62.615035282610215, 27.326346677845315, 187.61440648361628) -> Reference: (41, 34, 159)
# 1710071297670.jpg: Computed Color Correction Matrix (M):
# [[ 0.894613    0.43215874  0.29297194]
#  [ 0.07941268  0.6790095   0.01319282]
#  [-0.03722756 -0.0162665   0.7908521 ]]
# 1710071297670.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1710071297670.jpg
# 1710071337640.jpg: Detected circles (x, y, radius):
# [[ 62 168  58]
#  [290 168  57]
#  [176 168  57]
#  [116  64  60]
#  [236  66  58]]
# 1710071337640.jpg: Measured colors (B, G, R):
# (96.72113289760348, 12.04054182059297, 16.30093776641091)
# (43.908234370399455, 24.93679458239278, 161.68269702620475)
# (64.13720679163805, 102.2686230248307, 60.20561389734027)
# (195.53060501373017, 153.50907963504295, 161.71768978651784)
# (18.723595718480627, 9.635218338543147, 12.24410343847684)
# 1710071337640.jpg: Matched Measured Colors to Reference Colors:
# Measured: (96.72113289760348, 12.04054182059297, 16.30093776641091) -> Reference: (67, 30, 28)
# Measured: (43.908234370399455, 24.93679458239278, 161.68269702620475) -> Reference: (41, 34, 159)
# Measured: (64.13720679163805, 102.2686230248307, 60.20561389734027) -> Reference: (29, 77, 53)
# Measured: (195.53060501373017, 153.50907963504295, 161.71768978651784) -> Reference: (255, 255, 255)
# Measured: (18.723595718480627, 9.635218338543147, 12.24410343847684) -> Reference: (0, 0, 0)
# 1710071337640.jpg: Computed Color Correction Matrix (M):
# [[1.0215461  0.49388304 0.358081  ]
#  [0.05672041 0.8001844  0.04666827]
#  [0.05960201 0.02962219 0.9416992 ]]
# 1710071337640.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1710071337640.jpg
# 1710071630023.jpg: Detected circles (x, y, radius):
# [[282  76  57]
#  [ 56  60  56]
#  [224 172  58]
#  [106 164  57]
#  [172  68  56]]
# 1710071630023.jpg: Measured colors (B, G, R):
# (106.00893120031407, 17.731278830110906, 20.96515850426931)
# (59.234636871508386, 41.22133062468258, 189.04723209751143)
# (247.74886320575976, 197.25198938992042, 196.99677908298597)
# (39.55039748748651, 22.139464127981157, 20.566689567180294)
# (68.10990350431692, 111.05982732351448, 65.68349415947182)
# 1710071630023.jpg: Matched Measured Colors to Reference Colors:
# Measured: (106.00893120031407, 17.731278830110906, 20.96515850426931) -> Reference: (67, 30, 28)
# Measured: (59.234636871508386, 41.22133062468258, 189.04723209751143) -> Reference: (41, 34, 159)
# Measured: (247.74886320575976, 197.25198938992042, 196.99677908298597) -> Reference: (255, 255, 255)
# Measured: (39.55039748748651, 22.139464127981157, 20.566689567180294) -> Reference: (0, 0, 0)
# Measured: (68.10990350431692, 111.05982732351448, 65.68349415947182) -> Reference: (29, 77, 53)
# 1710071630023.jpg: Computed Color Correction Matrix (M):
# [[ 0.8627782   0.3573079   0.25521642]
#  [ 0.07027289  0.7757207   0.08601691]
#  [-0.01007972 -0.05347256  0.7829444 ]]
# 1710071630023.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1710071630023.jpg
# 1710071681980.jpg: Detected circles (x, y, radius):
# [[ 46 152  56]
#  [156 164  54]
#  [220  72  56]
#  [108  62  58]
#  [262 172  55]]
# 1710071681980.jpg: Measured colors (B, G, R):
# (98.95394388565379, 11.23652726310217, 14.0572789835892)
# (63.617386550027334, 105.53362493165665, 57.590595954073265)
# (30.96414423565262, 17.60558659217877, 19.331030980192992)
# (214.14549587951123, 166.39367244482335, 168.0055887089135)
# (51.923191173350304, 31.83778909399533, 169.79683853172077)
# 1710071681980.jpg: Matched Measured Colors to Reference Colors:
# Measured: (98.95394388565379, 11.23652726310217, 14.0572789835892) -> Reference: (67, 30, 28)
# Measured: (63.617386550027334, 105.53362493165665, 57.590595954073265) -> Reference: (29, 77, 53)
# Measured: (30.96414423565262, 17.60558659217877, 19.331030980192992) -> Reference: (0, 0, 0)
# Measured: (214.14549587951123, 166.39367244482335, 168.0055887089135) -> Reference: (255, 255, 255)
# Measured: (51.923191173350304, 31.83778909399533, 169.79683853172077) -> Reference: (41, 34, 159)
# 1710071681980.jpg: Computed Color Correction Matrix (M):
# [[ 0.9701165   0.46900976  0.34236667]
#  [ 0.06946839  0.781945    0.07542094]
#  [ 0.01149979 -0.02327003  0.8696627 ]]
# 1710071681980.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1710071681980.jpg
# 1710072075856.jpg: Detected circles (x, y, radius):
# [[138 204  70]
#  [348  76  70]
#  [284 200  70]
#  [ 74  78  69]
#  [212  78  69]]
# 1710072075856.jpg: Measured colors (B, G, R):
# (24.23085929877057, 11.823066415143433, 15.355753593963442)
# (98.1506537435764, 14.01873414427893, 26.4216483445001)
# (208.94724517010343, 164.59136147791583, 177.4644506602485)
# (51.84748143688541, 19.66318817312195, 163.08442036256605)
# (61.85142818917653, 103.288112917252, 73.92608201217473)
# 1710072075856.jpg: Matched Measured Colors to Reference Colors:
# Measured: (24.23085929877057, 11.823066415143433, 15.355753593963442) -> Reference: (0, 0, 0)
# Measured: (98.1506537435764, 14.01873414427893, 26.4216483445001) -> Reference: (67, 30, 28)
# Measured: (208.94724517010343, 164.59136147791583, 177.4644506602485) -> Reference: (255, 255, 255)
# Measured: (51.84748143688541, 19.66318817312195, 163.08442036256605) -> Reference: (41, 34, 159)
# Measured: (61.85142818917653, 103.288112917252, 73.92608201217473) -> Reference: (29, 77, 53)
# 1710072075856.jpg: Computed Color Correction Matrix (M):
# [[ 0.9920653   0.4475813   0.2961126 ]
#  [ 0.12229174  0.809056    0.01844637]
#  [-0.02735945  0.0105103   0.9207268 ]]
# 1710072075856.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1710072075856.jpg
# 1710072095533.jpg: Detected circles (x, y, radius):
# [[124 170  59]
#  [188  64  60]
#  [250 172  58]
#  [ 68  64  60]
#  [310  64  63]]
# 1710072095533.jpg: Measured colors (B, G, R):
# (63.53120131952717, 33.17676166040502, 32.3645193805553)
# (91.87722561785809, 138.78058286827886, 88.46602887766852)
# (254.42890972814246, 205.47447191436962, 204.96002652268638)
# (84.25502701745062, 52.94924262556471, 209.21817698644696)
# (131.6242672448406, 36.681843732433954, 46.737894483257044)
# 1710072095533.jpg: Matched Measured Colors to Reference Colors:
# Measured: (63.53120131952717, 33.17676166040502, 32.3645193805553) -> Reference: (67, 30, 28)
# Measured: (91.87722561785809, 138.78058286827886, 88.46602887766852) -> Reference: (29, 77, 53)
# Measured: (254.42890972814246, 205.47447191436962, 204.96002652268638) -> Reference: (255, 255, 255)
# Measured: (84.25502701745062, 52.94924262556471, 209.21817698644696) -> Reference: (41, 34, 159)
# Measured: (131.6242672448406, 36.681843732433954, 46.737894483257044) -> Reference: (0, 0, 0)
# 1710072095533.jpg: Computed Color Correction Matrix (M):
# [[ 0.39188245  0.11380634 -0.01871569]
#  [ 0.4526693   0.8995934   0.27733228]
#  [ 0.00963485 -0.04174995  0.7621622 ]]
# 1710072095533.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1710072095533.jpg
# 1710072332635.jpg: Detected circles (x, y, radius):
# [[258  68  63]
#  [200 180  62]
#  [128  72  64]
#  [322 176  62]
#  [ 76 184  63]]
# 1710072332635.jpg: Measured colors (B, G, R):
# (36.939211434995585, 17.91206938087208, 17.545330442463662)
# (66.36613879446149, 102.1942624989636, 52.3353784926623)
# (235.78752042324749, 177.2056329261651, 169.52882595502996)
# (49.13868065967017, 28.003664834249545, 161.72821922372148)
# (102.0223239380069, 14.852003533285153, 14.58604352364892)
# 1710072332635.jpg: Matched Measured Colors to Reference Colors:
# Measured: (36.939211434995585, 17.91206938087208, 17.545330442463662) -> Reference: (67, 30, 28)
# Measured: (66.36613879446149, 102.1942624989636, 52.3353784926623) -> Reference: (29, 77, 53)
# Measured: (235.78752042324749, 177.2056329261651, 169.52882595502996) -> Reference: (255, 255, 255)
# Measured: (49.13868065967017, 28.003664834249545, 161.72821922372148) -> Reference: (41, 34, 159)
# Measured: (102.0223239380069, 14.852003533285153, 14.58604352364892) -> Reference: (0, 0, 0)
# 1710072332635.jpg: Computed Color Correction Matrix (M):
# [[0.42835647 0.16305788 0.07324013]
#  [0.5033874  1.0013379  0.28215584]
#  [0.1592696  0.0696848  0.9779975 ]]
# 1710072332635.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1710072332635.jpg
# 1709791141427.jpg: Detected circles (x, y, radius):
# [[206 196  64]
#  [132  80  67]
#  [332 194  64]
#  [268  76  64]
#  [ 76 198  66]]
# 1709791141427.jpg: Measured colors (B, G, R):
# (57.378277444954485, 105.63922819575197, 89.59239088150626)
# (185.60456192709444, 183.42109003055495, 213.2129609891281)
# (59.24296051596665, 45.879738870536414, 199.2367468931886)
# (26.07554656500428, 25.83194584921808, 36.95938691356103)
# (77.56461639727931, 27.120822058070647, 41.87003583705112)
# 1709791141427.jpg: Matched Measured Colors to Reference Colors:
# Measured: (57.378277444954485, 105.63922819575197, 89.59239088150626) -> Reference: (29, 77, 53)
# Measured: (185.60456192709444, 183.42109003055495, 213.2129609891281) -> Reference: (255, 255, 255)
# Measured: (59.24296051596665, 45.879738870536414, 199.2367468931886) -> Reference: (41, 34, 159)
# Measured: (26.07554656500428, 25.83194584921808, 36.95938691356103) -> Reference: (67, 30, 28)
# Measured: (77.56461639727931, 27.120822058070647, 41.87003583705112) -> Reference: (0, 0, 0)
# 1709791141427.jpg: Computed Color Correction Matrix (M):
# [[ 0.5979886   0.20623194  0.05795887]
#  [ 0.60356694  1.1342001   0.25997603]
#  [-0.04982278 -0.11632817  0.7555895 ]]
# 1709791141427.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1709791141427.jpg
# 1709791532782.jpg: Detected circles (x, y, radius):
# [[120  68  63]
#  [176 184  62]
#  [250  82  62]
#  [296 194  60]
#  [ 54 170  63]]
# 1709791532782.jpg: Measured colors (B, G, R):
# (183.6881875853208, 179.78149843411225, 213.76206536577533)
# (65.77414808059034, 108.23953237708317, 96.70325843628223)
# (34.80664953154796, 33.89926208440428, 45.20354862780864)
# (59.575308422827725, 48.125232981272745, 195.71509718647377)
# (81.49255829336862, 29.95460558954854, 45.441872002645944)
# 1709791532782.jpg: Matched Measured Colors to Reference Colors:
# Measured: (183.6881875853208, 179.78149843411225, 213.76206536577533) -> Reference: (255, 255, 255)
# Measured: (65.77414808059034, 108.23953237708317, 96.70325843628223) -> Reference: (29, 77, 53)
# Measured: (34.80664953154796, 33.89926208440428, 45.20354862780864) -> Reference: (67, 30, 28)
# Measured: (59.575308422827725, 48.125232981272745, 195.71509718647377) -> Reference: (41, 34, 159)
# Measured: (81.49255829336862, 29.95460558954854, 45.441872002645944) -> Reference: (0, 0, 0)
# 1709791532782.jpg: Computed Color Correction Matrix (M):
# [[ 0.5261486   0.14389484 -0.01473927]
#  [ 0.6456604   1.188543    0.25076097]
#  [-0.04177515 -0.12094592  0.7961551 ]]
# 1709791532782.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1709791532782.jpg
# 1709791542264.jpg: Detected circles (x, y, radius):
# [[196 136  66]
#  [ 78 340  68]
#  [ 80  72  66]
#  [196 276  68]
#  [ 78 206  67]]
# 1709791542264.jpg: Measured colors (B, G, R):
# (230.21465662254076, 227.30834491333283, 245.43691947634022)
# (69.1116166839021, 64.53064460530851, 218.36242674939675)
# (100.03664155635192, 52.075404081035614, 62.2156074014481)
# (49.48776284039986, 50.6662530162013, 61.764770768700444)
# (78.60861223619698, 141.84331698998082, 103.59262417395011)
# 1709791542264.jpg: Matched Measured Colors to Reference Colors:
# Measured: (230.21465662254076, 227.30834491333283, 245.43691947634022) -> Reference: (255, 255, 255)
# Measured: (69.1116166839021, 64.53064460530851, 218.36242674939675) -> Reference: (41, 34, 159)
# Measured: (100.03664155635192, 52.075404081035614, 62.2156074014481) -> Reference: (67, 30, 28)
# Measured: (49.48776284039986, 50.6662530162013, 61.764770768700444) -> Reference: (29, 77, 53)
# Measured: (78.60861223619698, 141.84331698998082, 103.59262417395011) -> Reference: (0, 0, 0)
# 1709791542264.jpg: Computed Color Correction Matrix (M):
# [[ 1.5206451   1.1935833   0.76482016]
#  [-0.49626148 -0.21317552 -0.6433226 ]
#  [-0.1007945  -0.08097734  0.73409957]]
# 1709791542264.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1709791542264.jpg
# 1709791739978.jpg: Detected circles (x, y, radius):
# [[186  70  60]
#  [304  76  61]
#  [242 180  59]
#  [118 176  60]
#  [ 66  68  61]]
# 1709791739978.jpg: Measured colors (B, G, R):
# (71.86340685623172, 128.77349632385508, 106.06865089910532)
# (103.8292098279257, 59.43352452700967, 73.17181748138002)
# (230.73966828553102, 228.56565564006232, 254.1355264363603)
# (27.55018159270086, 26.823722207458587, 37.04172203029498)
# (63.654909682390205, 44.064378049824505, 223.05478982963788)
# 1709791739978.jpg: Matched Measured Colors to Reference Colors:
# Measured: (71.86340685623172, 128.77349632385508, 106.06865089910532) -> Reference: (29, 77, 53)
# Measured: (103.8292098279257, 59.43352452700967, 73.17181748138002) -> Reference: (67, 30, 28)
# Measured: (230.73966828553102, 228.56565564006232, 254.1355264363603) -> Reference: (255, 255, 255)
# Measured: (27.55018159270086, 26.823722207458587, 37.04172203029498) -> Reference: (0, 0, 0)
# Measured: (63.654909682390205, 44.064378049824505, 223.05478982963788) -> Reference: (41, 34, 159)
# 1709791739978.jpg: Computed Color Correction Matrix (M):
# [[ 1.166855    0.30988485  0.2065855 ]
#  [-0.07842042  0.7272102   0.00829271]
#  [-0.11485288 -0.06091357  0.6712593 ]]
# 1709791739978.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1709791739978.jpg
# 1709792080268.jpg: Detected circles (x, y, radius):
# [[202  72  65]
#  [270 188  64]
#  [334  74  65]
#  [136 188  65]
#  [ 74  72  64]]
# 1709792080268.jpg: Measured colors (B, G, R):
# (77.86619453024939, 135.49325698787013, 111.60521359150155)
# (230.1153816229674, 227.94203687854977, 254.371819808605)
# (99.93498078806601, 54.946809312137425, 67.71935508174491)
# (43.14533263015144, 39.95607624500867, 52.21442025163867)
# (70.61129697346922, 52.968412043880804, 230.05702948727924)
# 1709792080268.jpg: Matched Measured Colors to Reference Colors:
# Measured: (77.86619453024939, 135.49325698787013, 111.60521359150155) -> Reference: (29, 77, 53)
# Measured: (230.1153816229674, 227.94203687854977, 254.371819808605) -> Reference: (255, 255, 255)
# Measured: (99.93498078806601, 54.946809312137425, 67.71935508174491) -> Reference: (67, 30, 28)
# Measured: (43.14533263015144, 39.95607624500867, 52.21442025163867) -> Reference: (0, 0, 0)
# Measured: (70.61129697346922, 52.968412043880804, 230.05702948727924) -> Reference: (41, 34, 159)
# 1709792080268.jpg: Computed Color Correction Matrix (M):
# [[ 1.2434136   0.40397465  0.27945113]
#  [-0.12796313  0.6728087  -0.04045851]
#  [-0.15484461 -0.11166316  0.6338774 ]]
# 1709792080268.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1709792080268.jpg
# 1709792108689.jpg: Detected circles (x, y, radius):
# [[196 178  58]
#  [128  76  60]
#  [252  70  59]
#  [ 76 182  58]
#  [312 170  57]]
# 1709792108689.jpg: Measured colors (B, G, R):
# (63.44330775788576, 108.63682864450128, 90.72132234536326)
# (189.45876516963415, 187.55602799185047, 213.18850208167242)
# (30.867589113900852, 30.288096765325758, 40.92266104645835)
# (77.44747560860093, 26.48934356351236, 38.690158188879415)
# (60.67425655118265, 49.5533418392384, 194.18186279320838)
# 1709792108689.jpg: Matched Measured Colors to Reference Colors:
# Measured: (63.44330775788576, 108.63682864450128, 90.72132234536326) -> Reference: (29, 77, 53)
# Measured: (189.45876516963415, 187.55602799185047, 213.18850208167242) -> Reference: (255, 255, 255)
# Measured: (30.867589113900852, 30.288096765325758, 40.92266104645835) -> Reference: (67, 30, 28)
# Measured: (77.44747560860093, 26.48934356351236, 38.690158188879415) -> Reference: (0, 0, 0)
# Measured: (60.67425655118265, 49.5533418392384, 194.18186279320838) -> Reference: (41, 34, 159)
# 1709792108689.jpg: Computed Color Correction Matrix (M):
# [[ 0.5798298   0.19703378  0.04773092]
#  [ 0.586449    1.1232302   0.22384244]
#  [-0.04823275 -0.13122548  0.7868896 ]]
# 1709792108689.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1709792108689.jpg
# 1709792697759.jpg: Detected circles (x, y, radius):
# [[ 84 234  77]
#  [ 82 388  80]
#  [220 160  78]
#  [ 86  80  77]
#  [220 318  79]]
# 1709792697759.jpg: Measured colors (B, G, R):
# (64.72426766998119, 104.77312550389681, 87.30534802472454)
# (56.7339641434263, 45.079033864541834, 175.69915338645419)
# (182.57805840568273, 180.28255722178375, 202.9774796106288)
# (84.4806772373018, 43.600752485890894, 54.83504434291857)
# (44.034596375617795, 42.02105642504119, 52.032073723229)
# 1709792697759.jpg: Matched Measured Colors to Reference Colors:
# Measured: (64.72426766998119, 104.77312550389681, 87.30534802472454) -> Reference: (29, 77, 53)
# Measured: (56.7339641434263, 45.079033864541834, 175.69915338645419) -> Reference: (41, 34, 159)
# Measured: (182.57805840568273, 180.28255722178375, 202.9774796106288) -> Reference: (255, 255, 255)
# Measured: (84.4806772373018, 43.600752485890894, 54.83504434291857) -> Reference: (67, 30, 28)
# Measured: (44.034596375617795, 42.02105642504119, 52.032073723229) -> Reference: (0, 0, 0)
# 1709792697759.jpg: Computed Color Correction Matrix (M):
# [[ 1.3743699   0.33998576  0.15009311]
#  [-0.05067675  0.99062407  0.03113928]
#  [-0.16152066 -0.13881077  0.87930864]]
# 1709792697759.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1709792697759.jpg
# 1709792753872.jpg: Detected circles (x, y, radius):
# [[212 288  71]
#  [206 142  72]
#  [ 80  78  72]
#  [ 86 218  70]
#  [ 90 360  72]]
# 1709792753872.jpg: Measured colors (B, G, R):
# (42.50246648115355, 42.23779408044523, 52.755565393372116)
# (202.89187857890522, 201.7831414321778, 223.56215750261683)
# (92.71892124869157, 48.007327135028625, 60.17911458654023)
# (67.5036752748325, 120.40837832563585, 95.29369674103948)
# (62.58487777846191, 56.82168585678221, 203.79564066252075)
# 1709792753872.jpg: Matched Measured Colors to Reference Colors:
# Measured: (42.50246648115355, 42.23779408044523, 52.755565393372116) -> Reference: (67, 30, 28)
# Measured: (202.89187857890522, 201.7831414321778, 223.56215750261683) -> Reference: (255, 255, 255)
# Measured: (92.71892124869157, 48.007327135028625, 60.17911458654023) -> Reference: (29, 77, 53)
# Measured: (67.5036752748325, 120.40837832563585, 95.29369674103948) -> Reference: (41, 34, 159)
# Measured: (62.58487777846191, 56.82168585678221, 203.79564066252075) -> Reference: (0, 0, 0)
# 1709792753872.jpg: Computed Color Correction Matrix (M):
# [[ 0.9196595   1.5176178   0.05964504]
#  [ 0.54438055  0.07030571  1.7140472 ]
#  [-0.376197   -0.45341432 -0.49626485]]
# 1709792753872.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1709792753872.jpg
# 1709793075008.jpg: Detected circles (x, y, radius):
# [[206  76  67]
#  [340  82  67]
#  [268 198  68]
#  [130 192  68]
#  [ 72  70  68]]
# 1709793075008.jpg: Measured colors (B, G, R):
# (66.71882327861863, 121.02153059049243, 94.31613728416116)
# (92.05173026362537, 50.8519150145669, 61.97932210616073)
# (201.9973802137194, 205.54588073078247, 232.8802481902792)
# (29.657428472940364, 29.445225784212337, 39.11554636332299)
# (55.68362633574629, 40.93650465356773, 202.7151327128576)
# 1709793075008.jpg: Matched Measured Colors to Reference Colors:
# Measured: (66.71882327861863, 121.02153059049243, 94.31613728416116) -> Reference: (29, 77, 53)
# Measured: (92.05173026362537, 50.8519150145669, 61.97932210616073) -> Reference: (67, 30, 28)
# Measured: (201.9973802137194, 205.54588073078247, 232.8802481902792) -> Reference: (255, 255, 255)
# Measured: (29.657428472940364, 29.445225784212337, 39.11554636332299) -> Reference: (0, 0, 0)
# Measured: (55.68362633574629, 40.93650465356773, 202.7151327128576) -> Reference: (41, 34, 159)
# 1709793075008.jpg: Computed Color Correction Matrix (M):
# [[ 1.2958626   0.3748664   0.20158017]
#  [-0.10538612  0.7559808   0.00857157]
#  [-0.09561128 -0.05239749  0.76029783]]
# 1709793075008.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1709793075008.jpg
# 1709793178685.jpg: Detected circles (x, y, radius):
# [[196 184  62]
#  [264  76  63]
#  [130  72  65]
#  [320 186  61]
#  [ 70 186  66]]
# 1709793178685.jpg: Measured colors (B, G, R):
# (57.05687753917586, 103.51015670342426, 79.61396235801342)
# (25.018630048984182, 23.717337187826228, 30.41949730988517)
# (192.52693437806073, 189.72176599110978, 207.15196263090488)
# (55.23028850269669, 43.25169077989898, 186.26804211968152)
# (87.37350983690484, 39.21933738023842, 49.278651356688364)
# 1709793178685.jpg: Matched Measured Colors to Reference Colors:
# Measured: (57.05687753917586, 103.51015670342426, 79.61396235801342) -> Reference: (29, 77, 53)
# Measured: (25.018630048984182, 23.717337187826228, 30.41949730988517) -> Reference: (67, 30, 28)
# Measured: (192.52693437806073, 189.72176599110978, 207.15196263090488) -> Reference: (255, 255, 255)
# Measured: (55.23028850269669, 43.25169077989898, 186.26804211968152) -> Reference: (41, 34, 159)
# Measured: (87.37350983690484, 39.21933738023842, 49.278651356688364) -> Reference: (0, 0, 0)
# 1709793178685.jpg: Computed Color Correction Matrix (M):
# [[ 0.4078208  -0.02530936 -0.1552109 ]
#  [ 0.66452926  1.2349796   0.3727193 ]
#  [ 0.01967778 -0.04843227  0.8600034 ]]
# 1709793178685.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1709793178685.jpg
# 1709793369852.jpg: Detected circles (x, y, radius):
# [[146 194  66]
#  [286 186  67]
#  [210  74  66]
#  [344  66  66]
#  [ 76  80  66]]
# 1709793369852.jpg: Measured colors (B, G, R):
# (22.075769765230746, 19.75111533679514, 26.372485921158486)
# (219.75662616357562, 213.03950827826333, 235.53179847935763)
# (68.09076281723104, 127.12221165801213, 93.02311124113216)
# (101.72895487457032, 49.87654501572442, 62.57566005997221)
# (53.015943830907624, 33.87427777371462, 207.60659694288012)
# 1709793369852.jpg: Matched Measured Colors to Reference Colors:
# Measured: (22.075769765230746, 19.75111533679514, 26.372485921158486) -> Reference: (0, 0, 0)
# Measured: (219.75662616357562, 213.03950827826333, 235.53179847935763) -> Reference: (255, 255, 255)
# Measured: (68.09076281723104, 127.12221165801213, 93.02311124113216) -> Reference: (29, 77, 53)
# Measured: (101.72895487457032, 49.87654501572442, 62.57566005997221) -> Reference: (67, 30, 28)
# Measured: (53.015943830907624, 33.87427777371462, 207.60659694288012) -> Reference: (41, 34, 159)
# 1709793369852.jpg: Computed Color Correction Matrix (M):
# [[ 1.1116525   0.34473947  0.17416413]
#  [-0.06256129  0.69045454  0.03794286]
#  [-0.0405002  -0.00212715  0.7488356 ]]
# 1709793369852.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1709793369852.jpg
# 1709793732352.jpg: Detected circles (x, y, radius):
# [[248  64  60]
#  [124  66  63]
#  [188 174  61]
#  [308 170  60]
#  [ 68 178  62]]
# 1709793732352.jpg: Measured colors (B, G, R):
# (35.65169634157144, 31.27593232350075, 36.68021968287714)
# (231.90644824540271, 225.19031558660564, 245.3561390829519)
# (73.39791113774506, 128.8284393459464, 99.87081585480695)
# (65.93387769592616, 49.69690245850715, 220.24948966006923)
# (101.33781094527363, 61.7363184079602, 71.62562189054727)
# 1709793732352.jpg: Matched Measured Colors to Reference Colors:
# Measured: (35.65169634157144, 31.27593232350075, 36.68021968287714) -> Reference: (67, 30, 28)
# Measured: (231.90644824540271, 225.19031558660564, 245.3561390829519) -> Reference: (255, 255, 255)
# Measured: (73.39791113774506, 128.8284393459464, 99.87081585480695) -> Reference: (29, 77, 53)
# Measured: (65.93387769592616, 49.69690245850715, 220.24948966006923) -> Reference: (41, 34, 159)
# Measured: (101.33781094527363, 61.7363184079602, 71.62562189054727) -> Reference: (0, 0, 0)
# 1709793732352.jpg: Computed Color Correction Matrix (M):
# [[ 0.6346381   0.08391929 -0.02592082]
#  [ 0.27855554  0.8963999   0.17949827]
#  [-0.01630238 -0.03473806  0.7268942 ]]
# 1709793732352.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1709793732352.jpg
# 1709793881980.jpg: Detected circles (x, y, radius):
# [[ 70 200  66]
#  [190 134  63]
#  [ 70  70  63]
#  [188 272  69]
#  [ 72 330  67]]
# 1709793881980.jpg: Measured colors (B, G, R):
# (68.80282308198639, 124.25202954728296, 97.41007825641775)
# (201.1663053079579, 208.52935035734362, 229.85585802617842)
# (89.52236408897454, 49.02152091865414, 58.119087770015256)
# (46.35460565924142, 48.71509799986621, 59.558833366780384)
# (57.86889788957578, 54.3829318553258, 201.08733034889502)
# 1709793881980.jpg: Matched Measured Colors to Reference Colors:
# Measured: (68.80282308198639, 124.25202954728296, 97.41007825641775) -> Reference: (29, 77, 53)
# Measured: (201.1663053079579, 208.52935035734362, 229.85585802617842) -> Reference: (255, 255, 255)
# Measured: (89.52236408897454, 49.02152091865414, 58.119087770015256) -> Reference: (67, 30, 28)
# Measured: (46.35460565924142, 48.71509799986621, 59.558833366780384) -> Reference: (0, 0, 0)
# Measured: (57.86889788957578, 54.3829318553258, 201.08733034889502) -> Reference: (41, 34, 159)
# 1709793881980.jpg: Computed Color Correction Matrix (M):
# [[ 1.3570507   0.45540982  0.2755974 ]
#  [-0.16418782  0.72858    -0.07425667]
#  [-0.11186298 -0.12982348  0.75745964]]
# 1709793881980.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1709793881980.jpg
# 1709794390243.jpg: Detected circles (x, y, radius):
# [[130 188  66]
#  [332  76  66]
#  [266 190  68]
#  [ 70  68  67]
#  [204  72  66]]
# 1709794390243.jpg: Measured colors (B, G, R):
# (34.461347180574855, 30.167556498208146, 33.093249469757914)
# (106.35976011116799, 57.025524756820005, 66.69728662327213)
# (229.5786970010341, 221.0288176490865, 237.04591520165457)
# (65.34221559013714, 50.450650181198036, 209.1495061465217)
# (74.86579390038762, 134.52570759891756, 95.74555693702918)
# 1709794390243.jpg: Matched Measured Colors to Reference Colors:
# Measured: (34.461347180574855, 30.167556498208146, 33.093249469757914) -> Reference: (67, 30, 28)
# Measured: (106.35976011116799, 57.025524756820005, 66.69728662327213) -> Reference: (29, 77, 53)
# Measured: (229.5786970010341, 221.0288176490865, 237.04591520165457) -> Reference: (255, 255, 255)
# Measured: (65.34221559013714, 50.450650181198036, 209.1495061465217) -> Reference: (41, 34, 159)
# Measured: (74.86579390038762, 134.52570759891756, 95.74555693702918) -> Reference: (0, 0, 0)
# 1709794390243.jpg: Computed Color Correction Matrix (M):
# [[ 1.0818611   1.5419972   0.9134565 ]
#  [-0.16978785 -0.4555276  -0.7197695 ]
#  [-0.03018894 -0.15984944  0.6972164 ]]
# 1709794390243.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1709794390243.jpg
# 1709794451041.jpg: Detected circles (x, y, radius):
# [[ 68 180  62]
#  [126  72  63]
#  [314 184  60]
#  [258  74  63]
#  [190 184  60]]
# 1709794451041.jpg: Measured colors (B, G, R):
# (85.31083658071469, 28.49514965591576, 38.52433463228588)
# (206.06689151208545, 203.41789127117963, 219.34264835782542)
# (64.67694215608114, 53.57028966250332, 202.01497032509522)
# (35.730827912952705, 34.044888781819644, 41.74263229743837)
# (63.509788289485336, 117.58517140579325, 85.39259456107715)
# 1709794451041.jpg: Matched Measured Colors to Reference Colors:
# Measured: (85.31083658071469, 28.49514965591576, 38.52433463228588) -> Reference: (67, 30, 28)
# Measured: (206.06689151208545, 203.41789127117963, 219.34264835782542) -> Reference: (255, 255, 255)
# Measured: (64.67694215608114, 53.57028966250332, 202.01497032509522) -> Reference: (41, 34, 159)
# Measured: (35.730827912952705, 34.044888781819644, 41.74263229743837) -> Reference: (29, 77, 53)
# Measured: (63.509788289485336, 117.58517140579325, 85.39259456107715) -> Reference: (0, 0, 0)
# 1709794451041.jpg: Computed Color Correction Matrix (M):
# [[ 1.4777639   1.1160423   0.74220306]
#  [-0.2837032   0.03207008 -0.49135002]
#  [-0.13956717 -0.11485582  0.7435633 ]]
# 1709794451041.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1709794451041.jpg
# 1709794454933.jpg: Detected circles (x, y, radius):
# [[200 190  65]
#  [ 68 192  67]
#  [130  72  69]
#  [268  76  65]
#  [332 190  66]]
# 1709794454933.jpg: Measured colors (B, G, R):
# (68.55707074512168, 116.35304754011905, 92.06034807503956)
# (83.10374475946848, 34.332338520571305, 46.65849499040716)
# (192.55187637969095, 191.3433674493277, 212.17673422971436)
# (42.579823702252696, 41.88631055526257, 51.48979130565811)
# (64.22839829430687, 55.31540360589511, 197.14752749307996)
# 1709794454933.jpg: Matched Measured Colors to Reference Colors:
# Measured: (68.55707074512168, 116.35304754011905, 92.06034807503956) -> Reference: (29, 77, 53)
# Measured: (83.10374475946848, 34.332338520571305, 46.65849499040716) -> Reference: (67, 30, 28)
# Measured: (192.55187637969095, 191.3433674493277, 212.17673422971436) -> Reference: (255, 255, 255)
# Measured: (42.579823702252696, 41.88631055526257, 51.48979130565811) -> Reference: (0, 0, 0)
# Measured: (64.22839829430687, 55.31540360589511, 197.14752749307996) -> Reference: (41, 34, 159)
# 1709794454933.jpg: Computed Color Correction Matrix (M):
# [[ 1.4023978   0.5487263   0.33520663]
#  [-0.08986121  0.79947704 -0.02320964]
#  [-0.19038956 -0.20175692  0.7313416 ]]
# 1709794454933.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1709794454933.jpg
# 1709794959069.jpg: Detected circles (x, y, radius):
# [[226  82  73]
#  [ 80  80  74]
#  [300 212  71]
#  [146 208  72]
#  [372  80  72]]
# 1709794959069.jpg: Measured colors (B, G, R):
# (71.94984757008787, 116.33020503317593, 99.40594177775121)
# (67.81713488047461, 54.73669516663759, 201.70296050718315)
# (209.89034338835134, 203.52956428255231, 225.96230949218995)
# (48.38839972908072, 44.2081768364017, 56.49596699710609)
# (94.10462739267795, 58.30341324413059, 69.59629560800347)
# 1709794959069.jpg: Matched Measured Colors to Reference Colors:
# Measured: (71.94984757008787, 116.33020503317593, 99.40594177775121) -> Reference: (29, 77, 53)
# Measured: (67.81713488047461, 54.73669516663759, 201.70296050718315) -> Reference: (41, 34, 159)
# Measured: (209.89034338835134, 203.52956428255231, 225.96230949218995) -> Reference: (255, 255, 255)
# Measured: (48.38839972908072, 44.2081768364017, 56.49596699710609) -> Reference: (67, 30, 28)
# Measured: (94.10462739267795, 58.30341324413059, 69.59629560800347) -> Reference: (0, 0, 0)
# 1709794959069.jpg: Computed Color Correction Matrix (M):
# [[ 0.644711    0.01195629 -0.08473516]
#  [ 0.40382987  1.129853    0.22307374]
#  [-0.07095931 -0.10950091  0.7874165 ]]
# 1709794959069.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1709794959069.jpg
# 1709795076038.jpg: Detected circles (x, y, radius):
# [[166 248  61]
#  [ 62 182  60]
#  [ 58 300  61]
#  [168 126  60]
#  [ 66  62  60]]
# 1709795076038.jpg: Measured colors (B, G, R):
# (47.28182518619981, 48.11728447906857, 57.22814827497646)
# (74.48099920276375, 128.0779519886615, 99.68358579147842)
# (63.02167555479098, 59.278169619817646, 200.43884397041114)
# (196.66480644875543, 203.95048277083885, 224.50890247143235)
# (99.7445300735229, 56.14128797944902, 65.66781823013552)
# 1709795076038.jpg: Matched Measured Colors to Reference Colors:
# Measured: (47.28182518619981, 48.11728447906857, 57.22814827497646) -> Reference: (29, 77, 53)
# Measured: (74.48099920276375, 128.0779519886615, 99.68358579147842) -> Reference: (41, 34, 159)
# Measured: (63.02167555479098, 59.278169619817646, 200.43884397041114) -> Reference: (67, 30, 28)
# Measured: (196.66480644875543, 203.95048277083885, 224.50890247143235) -> Reference: (255, 255, 255)
# Measured: (99.7445300735229, 56.14128797944902, 65.66781823013552) -> Reference: (0, 0, 0)
# 1709795076038.jpg: Computed Color Correction Matrix (M):
# [[ 0.20725134  0.425228   -0.7272414 ]
#  [ 0.52051824  0.60756373  2.031434  ]
#  [ 0.1959559  -0.0637261  -0.19426271]]
# 1709795076038.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1709795076038.jpg
# 1709795312517.jpg: Detected circles (x, y, radius):
# [[254 168  85]
#  [116 432  86]
#  [108 262  85]
#  [262 346  86]
#  [100  92  86]]
# 1709795312517.jpg: Measured colors (B, G, R):
# (199.811109642747, 192.42747015549975, 207.70521122417514)
# (58.38445966317785, 45.09462893569368, 181.63724856785976)
# (66.3260649310603, 110.36998370115853, 85.42297696136734)
# (44.76708882720333, 40.60127515614157, 46.74874219292158)
# (91.21225825903433, 41.80212775121679, 50.21639316018435)
# 1709795312517.jpg: Matched Measured Colors to Reference Colors:
# Measured: (199.811109642747, 192.42747015549975, 207.70521122417514) -> Reference: (255, 255, 255)
# Measured: (58.38445966317785, 45.09462893569368, 181.63724856785976) -> Reference: (41, 34, 159)
# Measured: (66.3260649310603, 110.36998370115853, 85.42297696136734) -> Reference: (29, 77, 53)
# Measured: (44.76708882720333, 40.60127515614157, 46.74874219292158) -> Reference: (67, 30, 28)
# Measured: (91.21225825903433, 41.80212775121679, 50.21639316018435) -> Reference: (0, 0, 0)
# 1709795312517.jpg: Computed Color Correction Matrix (M):
# [[ 0.4275775  -0.02491781 -0.15895481]
#  [ 0.59081084  1.1753507   0.2921083 ]
#  [ 0.02361305 -0.04149069  0.9069455 ]]
# 1709795312517.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1709795312517.jpg
# 1709795322859.jpg: Detected circles (x, y, radius):
# [[148  78  68]
#  [288  84  68]
#  [ 82 194  66]
#  [346 204  66]
#  [212 198  66]]
# 1709795322859.jpg: Measured colors (B, G, R):
# (188.48114443295412, 181.47556015167183, 193.9235436056532)
# (23.55953119613926, 22.139469148569457, 27.480661840744567)
# (76.03349667227383, 19.65515980399327, 27.06450669202077)
# (57.07759818620639, 48.14839464638338, 186.9662839172091)
# (57.89526804651503, 107.57134498646968, 76.20573392817963)
# 1709795322859.jpg: Matched Measured Colors to Reference Colors:
# Measured: (188.48114443295412, 181.47556015167183, 193.9235436056532) -> Reference: (255, 255, 255)
# Measured: (23.55953119613926, 22.139469148569457, 27.480661840744567) -> Reference: (0, 0, 0)
# Measured: (76.03349667227383, 19.65515980399327, 27.06450669202077) -> Reference: (67, 30, 28)
# Measured: (57.07759818620639, 48.14839464638338, 186.9662839172091) -> Reference: (41, 34, 159)
# ...
# 1709636926027.jpg: Computed Color Correction Matrix (M):
# [[ 0.9609342   1.6010705   0.33348536]
#  [ 0.7480786   0.2647706   1.7288393 ]
#  [-0.3993745  -0.51294935 -0.5026563 ]]
# 1709636926027.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1709636926027.jpg
# 1709637558250.jpg: Detected circles (x, y, radius):
# [[126  72  64]
#  [322 182  64]
#  [198 186  65]
#  [262  74  62]
#  [ 70 192  66]]
# 1709637558250.jpg: Measured colors (B, G, R):
# (184.70676106745506, 179.89621100132265, 210.63098109390805)
# (64.62421224616821, 53.59705905236132, 199.27402162919162)
# (66.92782340088903, 118.62894598056205, 112.81564077450464)
# (26.4001326589835, 30.752508083906807, 54.93673824724318)
# (86.26028202115158, 34.54590188014101, 54.22113689776733)
# 1709637558250.jpg: Matched Measured Colors to Reference Colors:
# Measured: (184.70676106745506, 179.89621100132265, 210.63098109390805) -> Reference: (255, 255, 255)
# Measured: (64.62421224616821, 53.59705905236132, 199.27402162919162) -> Reference: (41, 34, 159)
# Measured: (66.92782340088903, 118.62894598056205, 112.81564077450464) -> Reference: (29, 77, 53)
# Measured: (26.4001326589835, 30.752508083906807, 54.93673824724318) -> Reference: (67, 30, 28)
# Measured: (86.26028202115158, 34.54590188014101, 54.22113689776733) -> Reference: (0, 0, 0)
# 1709637558250.jpg: Computed Color Correction Matrix (M):
# [[ 0.63576245  0.30954412  0.1920913 ]
#  [ 0.5616614   1.0883325   0.10545859]
#  [-0.09325466 -0.20189829  0.714562  ]]
# 1709637558250.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1709637558250.jpg
# 1709637756921.jpg: Detected circles (x, y, radius):
# [[208 184  64]
#  [136  74  65]
#  [ 82 192  65]
#  [270  68  64]
#  [334 180  62]]
# 1709637756921.jpg: Measured colors (B, G, R):
# (69.53901812806349, 112.05103866801525, 100.76558002022874)
# (183.1137647856551, 174.0294582988021, 196.11640171777293)
# (86.11015672091621, 31.58958710066305, 47.50926763110307)
# (39.66778184081537, 36.05702948727924, 47.634015404963826)
# (62.121435759812144, 46.87940288493794, 181.55216370345522)
# 1709637756921.jpg: Matched Measured Colors to Reference Colors:
# Measured: (69.53901812806349, 112.05103866801525, 100.76558002022874) -> Reference: (29, 77, 53)
# Measured: (183.1137647856551, 174.0294582988021, 196.11640171777293) -> Reference: (255, 255, 255)
# Measured: (86.11015672091621, 31.58958710066305, 47.50926763110307) -> Reference: (67, 30, 28)
# Measured: (39.66778184081537, 36.05702948727924, 47.634015404963826) -> Reference: (0, 0, 0)
# Measured: (62.121435759812144, 46.87940288493794, 181.55216370345522) -> Reference: (41, 34, 159)
# 1709637756921.jpg: Computed Color Correction Matrix (M):
# [[ 1.3523507   0.5371626   0.35806733]
#  [ 0.0330646   0.9058448  -0.05896887]
#  [-0.22893867 -0.21750534  0.78243536]]
# 1709637756921.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1709637756921.jpg
# 1709638398656.jpg: Detected circles (x, y, radius):
# [[ 60 164  54]
#  [ 60 272  54]
#  [154 112  54]
#  [ 58  60  53]
#  [154 222  54]]
# 1709638398656.jpg: Measured colors (B, G, R):
# (68.35101148168398, 121.05893931109897, 106.62547840349917)
# (62.11897211591033, 51.2159650082012, 216.26265718972115)
# (226.96161837069437, 214.6449425915801, 245.87971569163477)
# (96.27381087524124, 40.32557611533659, 61.13406743103644)
# (40.437725533078186, 39.49677419354839, 58.44373974849645)
# 1709638398656.jpg: Matched Measured Colors to Reference Colors:
# Measured: (68.35101148168398, 121.05893931109897, 106.62547840349917) -> Reference: (29, 77, 53)
# Measured: (62.11897211591033, 51.2159650082012, 216.26265718972115) -> Reference: (41, 34, 159)
# Measured: (226.96161837069437, 214.6449425915801, 245.87971569163477) -> Reference: (255, 255, 255)
# Measured: (96.27381087524124, 40.32557611533659, 61.13406743103644) -> Reference: (67, 30, 28)
# Measured: (40.437725533078186, 39.49677419354839, 58.44373974849645) -> Reference: (0, 0, 0)
# 1709638398656.jpg: Computed Color Correction Matrix (M):
# [[ 1.1749977   0.4336001   0.2837718 ]
#  [-0.0416746   0.7637495  -0.02428704]
#  [-0.1388461  -0.15057413  0.6550471 ]]
# 1709638398656.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1709638398656.jpg
# 1709638424302.jpg: Detected circles (x, y, radius):
# [[262 168  54]
#  [108  60  56]
#  [ 48 154  54]
#  [222  68  56]
#  [156 158  56]]
# 1709638424302.jpg: Measured colors (B, G, R):
# (62.874821878767946, 47.11268223172202, 191.7711279184479)
# (185.9042153377349, 178.25027932960896, 204.78171660741495)
# (89.0998551209183, 28.088264794383146, 46.85991307255098)
# (42.338953783646524, 41.549619095987815, 57.78070086338243)
# (75.60071102082276, 121.1433214829863, 111.98313864906044)
# 1709638424302.jpg: Matched Measured Colors to Reference Colors:
# Measured: (62.874821878767946, 47.11268223172202, 191.7711279184479) -> Reference: (41, 34, 159)
# Measured: (185.9042153377349, 178.25027932960896, 204.78171660741495) -> Reference: (255, 255, 255)
# Measured: (89.0998551209183, 28.088264794383146, 46.85991307255098) -> Reference: (67, 30, 28)
# Measured: (42.338953783646524, 41.549619095987815, 57.78070086338243) -> Reference: (29, 77, 53)
# Measured: (75.60071102082276, 121.1433214829863, 111.98313864906044) -> Reference: (0, 0, 0)
# 1709638424302.jpg: Computed Color Correction Matrix (M):
# [[ 1.5216223   1.1120611   0.7665002 ]
#  [-0.24907531  0.112821   -0.5862548 ]
#  [-0.19308853 -0.15514562  0.76381385]]
# 1709638424302.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1709638424302.jpg
# 1709638555833.jpg: Detected circles (x, y, radius):
# [[110 174  62]
#  [304  82  61]
#  [238 186  62]
#  [ 62  60  60]
#  [184  72  60]]
# 1709638555833.jpg: Measured colors (B, G, R):
# (35.51488267971147, 32.47475333720255, 43.46878368294503)
# (98.73264275318894, 26.23097337556716, 40.56587620922866)
# (207.06517412935324, 191.67064676616914, 204.1922056384743)
# (63.02958632296926, 47.70156789795376, 196.4377712817787)
# (71.70714855168748, 122.30436708300114, 95.6717158295686)
# 1709638555833.jpg: Matched Measured Colors to Reference Colors:
# Measured: (35.51488267971147, 32.47475333720255, 43.46878368294503) -> Reference: (67, 30, 28)
# Measured: (98.73264275318894, 26.23097337556716, 40.56587620922866) -> Reference: (29, 77, 53)
# Measured: (207.06517412935324, 191.67064676616914, 204.1922056384743) -> Reference: (255, 255, 255)
# Measured: (63.02958632296926, 47.70156789795376, 196.4377712817787) -> Reference: (41, 34, 159)
# Measured: (71.70714855168748, 122.30436708300114, 95.6717158295686) -> Reference: (0, 0, 0)
# 1709638555833.jpg: Computed Color Correction Matrix (M):
# [[ 0.90681297  1.3816172   0.8729579 ]
#  [ 0.10550335 -0.21561792 -0.6240781 ]
#  [-0.03466965 -0.17183998  0.72323096]]
# 1709638555833.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1709638555833.jpg
# 1709639482872.jpg: Detected circles (x, y, radius):
# [[154  86  85]
#  [326  94  84]
#  [398 242  80]
#  [238 236  83]
#  [ 72 232  84]]
# 1709639482872.jpg: Measured colors (B, G, R):
# (226.1951015373772, 186.07444605964494, 187.7023479141888)
# (49.96769529661591, 30.554737270139608, 34.34861970812813)
# (63.09800308749564, 37.59115581893332, 177.95239280912304)
# (81.94248462712099, 125.34874474085719, 72.84428313837903)
# (121.1746822477769, 24.636342474044415, 27.69328181014014)
# 1709639482872.jpg: Matched Measured Colors to Reference Colors:
# Measured: (226.1951015373772, 186.07444605964494, 187.7023479141888) -> Reference: (255, 255, 255)
# Measured: (49.96769529661591, 30.554737270139608, 34.34861970812813) -> Reference: (67, 30, 28)
# Measured: (63.09800308749564, 37.59115581893332, 177.95239280912304) -> Reference: (41, 34, 159)
# Measured: (81.94248462712099, 125.34874474085719, 72.84428313837903) -> Reference: (29, 77, 53)
# Measured: (121.1746822477769, 24.636342474044415, 27.69328181014014) -> Reference: (0, 0, 0)
# 1709639482872.jpg: Computed Color Correction Matrix (M):
# [[ 0.31511435  0.09666732 -0.02108611]
#  [ 0.51252586  0.9375927   0.24128903]
#  [ 0.1656173   0.06868668  0.93973297]]
# 1709639482872.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1709639482872.jpg
# 1709639787868.jpg: Detected circles (x, y, radius):
# [[ 76 192  62]
#  [ 82 314  61]
#  [184 124  64]
#  [188 252  61]
#  [ 72  70  63]]
# 1709639787868.jpg: Measured colors (B, G, R):
# (86.94279081336539, 134.4022054556007, 88.23256778044939)
# (61.33524527009674, 45.01874839482921, 177.9504323259995)
# (221.19942421413012, 186.92818238406474, 193.34593837535016)
# (35.85562323067684, 25.43021360555889, 29.37565411340825)
# (131.1141090500281, 32.69565566530154, 40.88709547900105)
# 1709639787868.jpg: Matched Measured Colors to Reference Colors:
# Measured: (86.94279081336539, 134.4022054556007, 88.23256778044939) -> Reference: (29, 77, 53)
# Measured: (61.33524527009674, 45.01874839482921, 177.9504323259995) -> Reference: (41, 34, 159)
# Measured: (221.19942421413012, 186.92818238406474, 193.34593837535016) -> Reference: (255, 255, 255)
# Measured: (35.85562323067684, 25.43021360555889, 29.37565411340825) -> Reference: (67, 30, 28)
# Measured: (131.1141090500281, 32.69565566530154, 40.88709547900105) -> Reference: (0, 0, 0)
# 1709639787868.jpg: Computed Color Correction Matrix (M):
# [[ 0.28507313  0.09331729 -0.05541693]
#  [ 0.5008759   0.92174447  0.1734599 ]
#  [ 0.16012196  0.03975938  0.9673141 ]]
# 1709639787868.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1709639787868.jpg
# 1709639981572.jpg: Detected circles (x, y, radius):
# [[122  70  61]
#  [ 62 178  62]
#  [250  70  61]
#  [188 180  62]
#  [308 182  62]]
# 1709639981572.jpg: Measured colors (B, G, R):
# (236.22438147418885, 194.62357674856605, 199.91267870901464)
# (124.43221955061769, 36.77373352126689, 38.05895033579305)
# (67.72442427874326, 38.752846502867904, 40.35827412036641)
# (94.98333471519774, 127.12395323770832, 81.4150567946273)
# (80.41621756073295, 54.944117403200394, 189.78932095182822)
# 1709639981572.jpg: Matched Measured Colors to Reference Colors:
# Measured: (236.22438147418885, 194.62357674856605, 199.91267870901464) -> Reference: (255, 255, 255)
# Measured: (124.43221955061769, 36.77373352126689, 38.05895033579305) -> Reference: (67, 30, 28)
# Measured: (67.72442427874326, 38.752846502867904, 40.35827412036641) -> Reference: (29, 77, 53)
# Measured: (94.98333471519774, 127.12395323770832, 81.4150567946273) -> Reference: (41, 34, 159)
# Measured: (80.41621756073295, 54.944117403200394, 189.78932095182822) -> Reference: (0, 0, 0)
# 1709639981572.jpg: Computed Color Correction Matrix (M):
# [[ 0.7861604   0.6063253  -0.02170316]
#  [ 0.4167975   0.55529076  1.7100909 ]
#  [-0.34019315 -0.27888232 -0.44721115]]
# 1709639981572.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1709639981572.jpg
# 1709640736974.jpg: Detected circles (x, y, radius):
# [[ 78  76  68]
#  [ 74 352  70]
#  [198 144  68]
#  [ 74 212  69]
#  [196 288  69]]
# 1709640736974.jpg: Measured colors (B, G, R):
# (102.5208548776284, 41.33912443984833, 45.50927266459841)
# (38.598321732908346, 50.22799713783907, 187.79581083718207)
# (200.1172009651844, 203.70706652878314, 208.65108583247155)
# (36.055053849755836, 137.29312997524917, 92.42658371797445)
# (22.425914776908154, 27.607064017660043, 35.05211050906415)
# 1709640736974.jpg: Matched Measured Colors to Reference Colors:
# Measured: (102.5208548776284, 41.33912443984833, 45.50927266459841) -> Reference: (67, 30, 28)
# Measured: (38.598321732908346, 50.22799713783907, 187.79581083718207) -> Reference: (41, 34, 159)
# Measured: (200.1172009651844, 203.70706652878314, 208.65108583247155) -> Reference: (255, 255, 255)
# Measured: (36.055053849755836, 137.29312997524917, 92.42658371797445) -> Reference: (29, 77, 53)
# Measured: (22.425914776908154, 27.607064017660043, 35.05211050906415) -> Reference: (0, 0, 0)
# 1709640736974.jpg: Computed Color Correction Matrix (M):
# [[ 0.9994803   0.49824715  0.34772462]
#  [ 0.11006392  0.6657441  -0.09025377]
#  [ 0.0160096  -0.06222298  0.82998735]]
# 1709640736974.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1709640736974.jpg
# 1709640922586.jpg: Detected circles (x, y, radius):
# [[ 82 210  70]
#  [148  84  71]
#  [354 204  69]
#  [222 206  70]
#  [292  78  68]]
# 1709640922586.jpg: Measured colors (B, G, R):
# (115.92155077083198, 32.12606517921031, 41.98445326221297)
# (221.0211218617593, 194.10301650540694, 203.02852083728575)
# (65.94180212723259, 46.52465047829286, 191.64164827078736)
# (79.66753398816107, 127.51577440967931, 90.10505431600859)
# (33.61944157187177, 26.61461564977594, 32.790830748017925)
# 1709640922586.jpg: Matched Measured Colors to Reference Colors:
# Measured: (115.92155077083198, 32.12606517921031, 41.98445326221297) -> Reference: (67, 30, 28)
# Measured: (221.0211218617593, 194.10301650540694, 203.02852083728575) -> Reference: (255, 255, 255)
# Measured: (65.94180212723259, 46.52465047829286, 191.64164827078736) -> Reference: (41, 34, 159)
# Measured: (79.66753398816107, 127.51577440967931, 90.10505431600859) -> Reference: (29, 77, 53)
# Measured: (33.61944157187177, 26.61461564977594, 32.790830748017925) -> Reference: (0, 0, 0)
# 1709640922586.jpg: Computed Color Correction Matrix (M):
# [[ 0.90540975  0.35851938  0.20664154]
#  [ 0.10304209  0.7809558   0.0444161 ]
#  [-0.05974597 -0.08204349  0.796793  ]]
# 1709640922586.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1709640922586.jpg
# 1709641895047.jpg: Detected circles (x, y, radius):
# [[ 72 210  68]
#  [ 74  76  68]
#  [ 72 342  69]
#  [194 140  70]
#  [192 282  70]]
# 1709641895047.jpg: Measured colors (B, G, R):
# (82.69713891761461, 108.26108238538434, 55.560978972768005)
# (135.8148224750086, 32.44108927955877, 20.1237504308859)
# (53.35888688206569, 24.683590875643855, 157.71757308181148)
# (224.52006765107657, 167.81434983412476, 157.9980485266376)
# (62.249008001040785, 32.53808625512262, 24.574513757887207)
# 1709641895047.jpg: Matched Measured Colors to Reference Colors:
# Measured: (82.69713891761461, 108.26108238538434, 55.560978972768005) -> Reference: (29, 77, 53)
# Measured: (135.8148224750086, 32.44108927955877, 20.1237504308859) -> Reference: (67, 30, 28)
# Measured: (53.35888688206569, 24.683590875643855, 157.71757308181148) -> Reference: (41, 34, 159)
# Measured: (224.52006765107657, 167.81434983412476, 157.9980485266376) -> Reference: (255, 255, 255)
# Measured: (62.249008001040785, 32.53808625512262, 24.574513757887207) -> Reference: (0, 0, 0)
# 1709641895047.jpg: Computed Color Correction Matrix (M):
# [[0.5750727  0.09792786 0.09553116]
#  [0.26459467 0.98445445 0.20870283]
#  [0.17355727 0.14985482 1.0370286 ]]
# 1709641895047.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1709641895047.jpg
# 1709642357991.jpg: Detected circles (x, y, radius):
# [[190 144  70]
#  [182 284  68]
#  [ 66 208  67]
#  [ 74  74  67]
#  [ 58 342  67]]
# 1709642357991.jpg: Measured colors (B, G, R):
# (220.71488974175503, 209.7258179925844, 211.36082742470566)
# (62.278938297138914, 55.862185453291964, 53.322026887280245)
# (60.98429505400796, 151.16493746446844, 93.20928084138714)
# (137.6749094009806, 62.545867974134865, 55.35919846514602)
# (11.447752481027438, 21.21957092819615, 201.63820782253356)
# 1709642357991.jpg: Matched Measured Colors to Reference Colors:
# Measured: (220.71488974175503, 209.7258179925844, 211.36082742470566) -> Reference: (255, 255, 255)
# Measured: (62.278938297138914, 55.862185453291964, 53.322026887280245) -> Reference: (67, 30, 28)
# Measured: (60.98429505400796, 151.16493746446844, 93.20928084138714) -> Reference: (29, 77, 53)
# Measured: (137.6749094009806, 62.545867974134865, 55.35919846514602) -> Reference: (41, 34, 159)
# Measured: (11.447752481027438, 21.21957092819615, 201.63820782253356) -> Reference: (0, 0, 0)
# 1709642357991.jpg: Computed Color Correction Matrix (M):
# [[ 0.6842723   0.34454498  1.235191  ]
#  [ 0.21133491  0.6236817  -0.09733263]
#  [ 0.02954995 -0.01161888 -0.05152792]]
# 1709642357991.jpg: Transformed image saved to ../Produced Images/Fingernail Transformed by 3x3 1/1709642357991.jpg
# Processing completed for all images.
